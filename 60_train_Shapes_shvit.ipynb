# %%
# # https://github.com/maxw1489/Mask_RCNN (tensorflow 2.9.1)

# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3" # https://stackoverflow.com/questions/35911252/disable-tensorflow-debugging-information


import tensorflow as tf
from tensorflow.python.client import device_lib

print(tf.__version__)
print("Num GPUs Available: ",
len(tf.config.list_physical_devices('GPU')))
device_lib.list_local_devices()
# Out:
# 2.15.0
# Num GPUs Available:  1
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 5440788945712351245
#  xla_global_id: -1,
#  name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 22500343808
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 5782971433702901719
#  physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:01:00.0, compute capability: 8.9"
#  xla_global_id: 416903419]

# %%
import logging
import os
import json
import cv2
import sys
import math
import random
import warnings

import cv2

import numpy as np
import matplotlib.pyplot as plt
import xml.etree.ElementTree as ET

dir_root = os.path.abspath("./")

# sys.path.append(os.path.join(dir_root, "maskrcnn/Mask_RCNN-master/"))  # To find local version
# sys.path.append(os.path.join(dir_root, "maskrcnn/Mask_RCNN-master_tf2p9/"))  # To find local version
# sys.path.append(os.path.join(dir_root, "maskrcnn/mask-rcnn-tf2-us-main/"))  # To find local version

# sys.path.append(os.path.join(dir_root, "maskrcnn/mask-rcnn-tf2-us-main/samples/coco/"))  # To find local version


from mrcnn import utils
from mrcnn import visualize
from mrcnn.visualize import display_images
import mrcnn.model as modellib
from mrcnn.model import log
from mrcnn.config import Config

import imgaug as ia
import imgaug.augmenters as iaa



logging.disable(logging.WARNING)
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
    # 0 = all messages are logged (default behavior)
    # 1 = INFO messages are not printed
    # 2 = INFO and WARNING messages are not printed
    # 3 = INFO, WARNING, and ERROR messages are not printed


warnings.filterwarnings('ignore')

# %%
# https://www.tensorflow.org/api_docs/python/tf/config/experimental/set_memory_growth
physical_devices = tf.config.list_physical_devices("GPU") 
for device in physical_devices:
    tf.config.experimental.set_memory_growth(device=device, enable=True)

tf.config.threading.set_intra_op_parallelism_threads(1)

# %%
NUM_OF_IMAGES = 10000
NUM_OF_VAL_IMAGES = int(NUM_OF_IMAGES*0.1)

# %%
class ShapesConfig(Config):
    """Configuration for training on the toy shapes dataset.
    Derives from the base Config class and overrides values specific
    to the toy shapes dataset.
    """
    # Give the configuration a recognizable name
    NAME = "60_shapes_shvit"
    BACKBONE = "shvit" # "resnet101"

    # The strides of each layer of the FPN Pyramid. These values
    # are based on a SHViT  backbone.
    BACKBONE_STRIDES = [8, 16, 32, 64, 128] # 128 added as they add 64 in the paper (original strides were [4,8,16,32] -> [4,8,16,32,64], maybe because P5 was upsampled by factor 2??)
    # BACKBONE_STRIDES= [4, 8, 16, 32, 64] # resnet


    # Train on 1 GPU and 8 images per GPU. We can put multiple images on each
    # GPU because the images are small. Batch size is 8 (GPUs * images/GPU).
    GPU_COUNT = 1
    IMAGES_PER_GPU = 4

    # Number of classes (including background)
    NUM_CLASSES = 1 + 3  # background + 3 shapes

    # Use small images for faster training. Set the limits of the small side
    # the large side, and that determines the image shape.
    IMAGE_MIN_DIM = 512 # 128
    IMAGE_MAX_DIM = 512 # 128

    # Use smaller anchors because our image and objects are small
    # RPN_ANCHOR_SCALES = (8, 16, 32, 64, 128)  # anchor side in pixels resnet
    RPN_ANCHOR_SCALES = (16, 32, 64, 128, 256) # anchor side in pixels shvit

    # Reduce training ROIs per image because the images are small and have
    # few objects. Aim to allow ROI sampling to pick 33% positive ROIs.
    TRAIN_ROIS_PER_IMAGE = 128 # 32

    # Use a small epoch since the data is simple
    STEPS_PER_EPOCH = int(NUM_OF_IMAGES / IMAGES_PER_GPU)

    # use small validation steps since the epoch is small
    VALIDATION_STEPS = int(NUM_OF_VAL_IMAGES / IMAGES_PER_GPU)

    RUN_EAGERLY = False    



config = ShapesConfig()
config.display()
# Out:
# Configurations:
# BACKBONE                       shvit
# BACKBONE_STRIDES               [8, 16, 32, 64, 128]
# BATCH_SIZE                     4
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        100
# DETECTION_MIN_CONFIDENCE       0.7
# DETECTION_NMS_THRESHOLD        0.3
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 4
# IMAGE_CHANNEL_COUNT            3
# IMAGE_MAX_DIM                  512
# IMAGE_META_SIZE                16
# IMAGE_MIN_DIM                  512
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              square
# IMAGE_SHAPE                    [512 512   3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.001
# LOSS_WEIGHTS                   {'rpn_class_loss': 1.0, 'rpn_bbox_loss': 1.0, 'mrcnn_class_loss': 1.0, 'mrcnn_bbox_loss': 1.0, 'mrcnn_mask_loss': 1.0}
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               100
# MEAN_PIXEL                     [123.7 116.8 103.9]
# MINI_MASK_SHAPE                (56, 56)
# NAME                           60_shapes_shvit
# NUM_CLASSES                    4
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        1000
# POST_NMS_ROIS_TRAINING         2000
# PRE_NMS_LIMIT                  6000
# ROI_POSITIVE_RATIO             0.33
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (16, 32, 64, 128, 256)
# RPN_ANCHOR_STRIDE              1
# RPN_BBOX_STD_DEV               [0.1 0.1 0.2 0.2]
# RPN_NMS_THRESHOLD              0.7
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# RUN_EAGERLY                    False
# STEPS_PER_EPOCH                2500
# TOP_DOWN_PYRAMID_SIZE          256
# TRAIN_BN                       False
# TRAIN_ROIS_PER_IMAGE           128
# USE_MINI_MASK                  False
# USE_RPN_ROIS                   True
# VALIDATION_STEPS               250
# WEIGHT_DECAY                   0.0001

# %%
class ShapesDataset(utils.Dataset):
    """Generates the shapes synthetic dataset. The dataset consists of simple
    shapes (triangles, squares, circles) placed randomly on a blank surface.
    The images are generated on the fly. No file access required.
    """

    def load_shapes(self, count, height, width):
        """Generate the requested number of synthetic images.
        count: number of images to generate.
        height, width: the size of the generated images.
        """
        # Add classes
        self.add_class("shapes", 1, "square")
        self.add_class("shapes", 2, "circle")
        self.add_class("shapes", 3, "triangle")

        # Add images
        # Generate random specifications of images (i.e. color and
        # list of shapes sizes and locations). This is more compact than
        # actual images. Images are generated on the fly in load_image().
        for i in range(count):
            bg_color, shapes = self.random_image(height, width)
            #print("bg_color", bg_color)
            #print("shapes", shapes)
            self.add_image("shapes", image_id=i, path=None,
                           width=width, height=height,
                           bg_color=bg_color, shapes=shapes)

    def load_image(self, image_id):
        """Generate an image from the specs of the given image ID.
        Typically this function loads the image from a file, but
        in this case it generates the image on the fly from the
        specs in image_info.
        """
        info = self.image_info[image_id]
        bg_color = np.array(info['bg_color']).reshape([1, 1, 3])
        image = np.ones([info['height'], info['width'], 3], dtype=np.uint8)
        image = image * bg_color.astype(np.uint8)
        for shape, color, dims in info['shapes']:
            image = self.draw_shape(image, shape, dims, color)
        return image

    def image_reference(self, image_id):
        """Return the shapes data of the image."""
        info = self.image_info[image_id]
        if info["source"] == "shapes":
            return info["shapes"]
        else:
            super(self.__class__).image_reference(self, image_id)

    def load_mask(self, image_id):
        """Generate instance masks for shapes of the given image ID.
        """
        info = self.image_info[image_id]
        shapes = info['shapes']
        count = len(shapes)
        mask = np.zeros([info['height'], info['width'], count], dtype=np.uint8)
        for i, (shape, _, dims) in enumerate(info['shapes']):
            mask[:, :, i:i + 1] = self.draw_shape(mask[:, :, i:i + 1].copy(),
                                                  shape, dims, 1)
        # Handle occlusions
        occlusion = np.logical_not(mask[:, :, -1]).astype(np.uint8)
        for i in range(count - 2, -1, -1):
            mask[:, :, i] = mask[:, :, i] * occlusion
            occlusion = np.logical_and(
                occlusion, np.logical_not(mask[:, :, i]))
        # Map class names to class IDs.
        class_ids = np.array([self.class_names.index(s[0]) for s in shapes])
        return mask, class_ids.astype(np.int32)

    def draw_shape(self, image, shape, dims, color):
        """Draws a shape from the given specs."""
        # Get the center x, y and the size s
        x, y, s = dims
        if shape == 'square':
            image = cv2.rectangle(image, (x - s, y - s),
                                  (x + s, y + s), color, -1)
        elif shape == "circle":
            image = cv2.circle(image, (x, y), s, color, -1)
        elif shape == "triangle":
            points = np.array([[(x, y - s),
                                (x - s / math.sin(math.radians(60)), y + s),
                                (x + s / math.sin(math.radians(60)), y + s),
                                ]], dtype=np.int32)
            image = cv2.fillPoly(image, points, color)
        return image

    def random_shape(self, height, width):
        """Generates specifications of a random shape that lies within
        the given height and width boundaries.
        Returns a tuple of three valus:
        * The shape name (square, circle, ...)
        * Shape color: a tuple of 3 values, RGB.
        * Shape dimensions: A tuple of values that define the shape size
                            and location. Differs per shape type.
        """
        # Shape
        shape = random.choice(["square", "circle", "triangle"])
        # Color
        color = tuple([random.randint(0, 255) for _ in range(3)])
        # Center x, y
        buffer = 20
        y = random.randint(buffer, height - buffer - 1)
        x = random.randint(buffer, width - buffer - 1)
        # Size
        s = random.randint(buffer, height // 4)
        return shape, color, (x, y, s)

    def random_image(self, height, width):
        """Creates random specifications of an image with multiple shapes.
        Returns the background color of the image and a list of shape
        specifications that can be used to draw the image.
        """
        # Pick random background color
        bg_color = np.array([random.randint(0, 255) for _ in range(3)])
        # Generate a few random shapes and record their
        # bounding boxes
        shapes = []
        boxes = []
        N = random.randint(1, 4)
        for _ in range(N):
            shape, color, dims = self.random_shape(height, width)
            shapes.append((shape, color, dims))
            x, y, s = dims
            boxes.append([y - s, x - s, y + s, x + s])
        # Apply non-max suppression wit 0.3 threshold to avoid
        # shapes covering each other
        keep_ixs = utils.non_max_suppression(
            np.array(boxes), np.arange(N), 0.3)
        shapes = [s for i, s in enumerate(shapes) if i in keep_ixs]
        return bg_color, shapes

# %%
# Training dataset
dataset_train = ShapesDataset()
dataset_train.load_shapes(NUM_OF_IMAGES, config.IMAGE_SHAPE[0], config.IMAGE_SHAPE[1])
dataset_train.prepare()

# Validation dataset
dataset_val = ShapesDataset()
dataset_val.load_shapes(NUM_OF_VAL_IMAGES, config.IMAGE_SHAPE[0], config.IMAGE_SHAPE[1])
dataset_val.prepare()

# %%
mask, idx = dataset_val.load_mask(2)
np.max(mask)
# Out:
# 1

# %%
# Load and display random samples
image_ids = np.random.choice(dataset_train.image_ids, 5)
for image_id in image_ids:
    image = dataset_train.load_image(image_id)
    cv2.imwrite(f"./shape_test_images/shape_test_image_{image_id}.png", image)
    mask, class_ids = dataset_train.load_mask(image_id)
    visualize.display_top_masks(image, mask, class_ids, dataset_train.class_names, limit=3)

# %% [markdown]
# ## Create Model and Load Trained Weights

# %%
sometimes = lambda aug: iaa.Sometimes(0.5, aug)

augmentation = iaa.Sequential([
                                iaa.Fliplr(0.5), 
                                iaa.Flipud(0.5),
                                #sometimes(iaa.Crop(percent=(0, 0.1))),
                                sometimes(iaa.Affine(
                                            #scale={"x": (0.8, 1.2), "y": (0.8, 1.2)},
                                            #translate_percent={"x": (-0.2, 0.2), "y": (-0.2, 0.2)},
                                            rotate=(-45, 45),
                                            #shear=(-16, 16),
                                            #order=[0, 1],
                                            #cval=(0, 255),
                                            #mode=ia.ALL
                                            )
                                        ),
                            ])

# %%
dir_model = os.path.join(dir_root, "logs/")

#COCO_MODEL_PATH = os.path.join(dir_root, "shoes/mask_rcnn_coco.h5")    
#if not os.path.exists(COCO_MODEL_PATH):
#    utils.download_trained_weights(COCO_MODEL_PATH)
    
# Create model object in inference mode.
model = modellib.MaskRCNN(mode="training", config=config, model_dir=dir_model)

# Load weights trained on MS-COCO
#model.load_weights(COCO_MOD
# EL_PATH, by_name=True, exclude=["mrcnn_class_logits", "mrcnn_bbox_fc", "mrcnn_bbox", "mrcnn_mask"])

# %%
EPOCHS = [1,500,200]
initial_learning_rate = 1e-3
warmup_epochs = 10


def lr_warmup(epoch, initial_learning_rate, warmup_epochs):
    if epoch < warmup_epochs:
        warmup_lr = initial_learning_rate * (epoch + 1) / (warmup_epochs)
        return warmup_lr
    return None  # Use None to indicate that the reduced learning rate should be used


class WarmupSchedulerWithReduceLROnPlateau(tf.keras.callbacks.Callback):
    def __init__(self, initial_learning_rate, warmup_epochs, reduce_lr_on_plateau):
        super(WarmupSchedulerWithReduceLROnPlateau, self).__init__()
        self.initial_learning_rate = initial_learning_rate
        self.warmup_epochs = warmup_epochs
        self.reduce_lr_on_plateau = reduce_lr_on_plateau

    def on_epoch_begin(self, epoch, logs=None):
        new_lr = lr_warmup(epoch, self.initial_learning_rate, self.warmup_epochs)
        if new_lr is not None:
            tf.keras.backend.set_value(self.model.optimizer.lr, new_lr)
            print(f"Epoch {epoch+1}: Learning rate is {new_lr:.6f} (warmup phase).")
        else:
            # Delegate to ReduceLROnPlateau's functionality
            self.reduce_lr_on_plateau.on_epoch_begin(epoch, logs)


reduce_lr_on_plateau  = tf.keras.callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.1, patience=10, min_lr=1e-8)
warmup_with_reduce_lr_callback = WarmupSchedulerWithReduceLROnPlateau(initial_learning_rate, warmup_epochs, reduce_lr_on_plateau)
stop_early = tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=50)

csv_logger_head = tf.keras.callbacks.CSVLogger(filename=config.NAME + "_training.log", append=False)
csv_logger_all = tf.keras.callbacks.CSVLogger(filename=config.NAME + "_training.log", append=True)

# %%
filename=config.NAME + "_training.log"
filename
# Out:
# '60_shapes_shvit_training.log'

# %%
model.compile(layers="head")
model.summary()
# Out:
# Selecting layers to train
# Model: "mask_rcnn"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_image (InputLayer)    [(None, None, None, 3)]      0         []
#
#  conv2d_bn (Conv2d_BN)       (None, None, None, 28)       868       ['input_image[0][0]']
#
#  conv2d_bn_1 (Conv2d_BN)     (None, None, None, 56)       14336     ['conv2d_bn[0][0]']
#
#  conv2d_bn_2 (Conv2d_BN)     (None, None, None, 112)      56896     ['conv2d_bn_1[0][0]']
#
#  conv2d_bn_3 (Conv2d_BN)     (None, None, None, 224)      226688    ['conv2d_bn_2[0][0]']
#
#  blocks1_i (Sequential)      (None, None, None, 224)      2623488   ['conv2d_bn_3[0][0]']
#
#  blocks2_s (Sequential)      (None, None, None, 336)      2143321   ['blocks1_i[0][0]']
#                                                           6
#
#  blocks3_s (Sequential)      (None, None, None, 448)      3930715   ['blocks2_s[0][0]']
#                                                           2
#
#  fpn_c5p5 (Conv2D)           (None, None, None, 256)      114944    ['blocks3_s[0][0]']
#
#  fpn_p5upsampled (UpSamplin  (None, None, None, 256)      0         ['fpn_c5p5[0][0]']
#  g2D)
#
#  fpn_c4p4 (Conv2D)           (None, None, None, 256)      86272     ['blocks2_s[0][0]']
#
#  fpn_p4add (Add)             (None, None, None, 256)      0         ['fpn_p5upsampled[0][0]',
#                                                                      'fpn_c4p4[0][0]']
#
#  fpn_p4upsampled (UpSamplin  (None, None, None, 256)      0         ['fpn_p4add[0][0]']
#  g2D)
#
#  fpn_c3p3 (Conv2D)           (None, None, None, 256)      57600     ['blocks1_i[0][0]']
#
#  fpn_p3add (Add)             (None, None, None, 256)      0         ['fpn_p4upsampled[0][0]',
#                                                                      'fpn_c3p3[0][0]']
#
#  fpn_p3upsampled (UpSamplin  (None, None, None, 256)      0         ['fpn_p3add[0][0]']
#  g2D)
#
#  fpn_c2p2 (Conv2D)           (None, None, None, 256)      28928     ['conv2d_bn_2[0][0]']
#
#  fpn_p2add (Add)             (None, None, None, 256)      0         ['fpn_p3upsampled[0][0]',
#                                                                      'fpn_c2p2[0][0]']
#
#  fpn_p5 (Conv2D)             (None, None, None, 256)      590080    ['fpn_c5p5[0][0]']
#
#  fpn_p2 (Conv2D)             (None, None, None, 256)      590080    ['fpn_p2add[0][0]']
#
#  fpn_p3 (Conv2D)             (None, None, None, 256)      590080    ['fpn_p3add[0][0]']
#
#  fpn_p4 (Conv2D)             (None, None, None, 256)      590080    ['fpn_p4add[0][0]']
#
#  fpn_p6 (MaxPooling2D)       (None, None, None, 256)      0         ['fpn_p5[0][0]']
#
#  rpn_model (Functional)      [(None, None, 2),            1189394   ['fpn_p2[0][0]',
#                               (None, None, 2),                       'fpn_p3[0][0]',
#                               (None, None, 4)]                       'fpn_p4[0][0]',
#                                                                      'fpn_p5[0][0]',
#                                                                      'fpn_p6[0][0]']
#
#  rpn_bbox (Concatenate)      (None, None, 4)              0         ['rpn_model[0][2]',
#                                                                      'rpn_model[1][2]',
#                                                                      'rpn_model[2][2]',
#                                                                      'rpn_model[3][2]',
#                                                                      'rpn_model[4][2]']
#
#  rpn_class (Concatenate)     (None, None, 2)              0         ['rpn_model[0][1]',
#                                                                      'rpn_model[1][1]',
#                                                                      'rpn_model[2][1]',
#                                                                      'rpn_model[3][1]',
#                                                                      'rpn_model[4][1]']
#
#  anchors (ConstLayer)        (4, 16368, 4)                261888    ['input_image[0][0]']
#
#  input_gt_boxes (InputLayer  [(None, None, 4)]            0         []
#  )
#
#  ROI (ProposalLayer)         (4, 2000, 4)                 0         ['rpn_class[0][0]',
#                                                                      'rpn_bbox[0][0]',
#                                                                      'anchors[0][0]']
#
#  input_gt_class_ids (InputL  [(None, None)]               0         []
#  ayer)
#
#  lambda (Lambda)             (None, None, 4)              0         ['input_gt_boxes[0][0]',
#                                                                      'input_image[0][0]']
#
#  input_gt_masks (InputLayer  [(None, 512, 512, None)]     0         []
#  )
#
#  proposal_targets (Detectio  [(4, None, 4),               0         ['ROI[0][0]',
#  nTargetLayer)                (4, None),                             'input_gt_class_ids[0][0]',
#                               (4, None, 4),                          'lambda[0][0]',
#                               (4, None, 28, 28)]                     'input_gt_masks[0][0]']
#
#  input_image_meta (InputLay  [(None, 16)]                 0         []
#  er)
#
#  roi_align_mask (PyramidROI  (4, None, 14, 14, 256)       0         ['proposal_targets[0][0]',
#  Align)                                                              'input_image_meta[0][0]',
#                                                                      'fpn_p2[0][0]',
#                                                                      'fpn_p3[0][0]',
#                                                                      'fpn_p4[0][0]',
#                                                                      'fpn_p5[0][0]']
#
#  mrcnn_mask_conv1 (TimeDist  (4, None, 14, 14, 256)       590080    ['roi_align_mask[0][0]']
#  ributed)
#
#  mrcnn_mask_bn1 (TimeDistri  (4, None, 14, 14, 256)       1024      ['mrcnn_mask_conv1[0][0]']
#  buted)
#
#  activation_106 (Activation  (4, None, 14, 14, 256)       0         ['mrcnn_mask_bn1[0][0]']
#  )
#
#  mrcnn_mask_conv2 (TimeDist  (4, None, 14, 14, 256)       590080    ['activation_106[0][0]']
#  ributed)
#
#  roi_align_classifier (Pyra  (4, None, 7, 7, 256)         0         ['proposal_targets[0][0]',
#  midROIAlign)                                                        'input_image_meta[0][0]',
#                                                                      'fpn_p2[0][0]',
#                                                                      'fpn_p3[0][0]',
#                                                                      'fpn_p4[0][0]',
#                                                                      'fpn_p5[0][0]']
#
#  mrcnn_mask_bn2 (TimeDistri  (4, None, 14, 14, 256)       1024      ['mrcnn_mask_conv2[0][0]']
#  buted)
#
#  mrcnn_class_conv1 (TimeDis  (4, None, 1, 1, 1024)        1284608   ['roi_align_classifier[0][0]']
#  tributed)                                                0
#
#  activation_107 (Activation  (4, None, 14, 14, 256)       0         ['mrcnn_mask_bn2[0][0]']
#  )
#
#  mrcnn_class_bn1 (TimeDistr  (4, None, 1, 1, 1024)        4096      ['mrcnn_class_conv1[0][0]']
#  ibuted)
#
#  mrcnn_mask_conv3 (TimeDist  (4, None, 14, 14, 256)       590080    ['activation_107[0][0]']
#  ributed)
#
#  activation_103 (Activation  (4, None, 1, 1, 1024)        0         ['mrcnn_class_bn1[0][0]']
#  )
#
#  mrcnn_mask_bn3 (TimeDistri  (4, None, 14, 14, 256)       1024      ['mrcnn_mask_conv3[0][0]']
#  buted)
#
#  mrcnn_class_conv2 (TimeDis  (4, None, 1, 1, 1024)        1049600   ['activation_103[0][0]']
#  tributed)
#
#  activation_108 (Activation  (4, None, 14, 14, 256)       0         ['mrcnn_mask_bn3[0][0]']
#  )
#
#  mrcnn_class_bn2 (TimeDistr  (4, None, 1, 1, 1024)        4096      ['mrcnn_class_conv2[0][0]']
#  ibuted)
#
#  mrcnn_mask_conv4 (TimeDist  (4, None, 14, 14, 256)       590080    ['activation_108[0][0]']
#  ributed)
#
#  activation_104 (Activation  (4, None, 1, 1, 1024)        0         ['mrcnn_class_bn2[0][0]']
#  )
#
#  mrcnn_mask_bn4 (TimeDistri  (4, None, 14, 14, 256)       1024      ['mrcnn_mask_conv4[0][0]']
#  buted)
#
#  pool_squeeze (Lambda)       (4, None, 1024)              0         ['activation_104[0][0]']
#
#  activation_109 (Activation  (4, None, 14, 14, 256)       0         ['mrcnn_mask_bn4[0][0]']
#  )
#
#  mrcnn_bbox_fc (TimeDistrib  (4, None, 16)                16400     ['pool_squeeze[0][0]']
#  uted)
#
#  mrcnn_mask_deconv (TimeDis  (4, None, 28, 28, 256)       262400    ['activation_109[0][0]']
#  tributed)
#
#  input_rpn_match (InputLaye  [(None, None, 1)]            0         []
#  r)
#
#  input_rpn_bbox (InputLayer  [(None, None, 4)]            0         []
#  )
#
#  rpn_class_logits (Concaten  (None, None, 2)              0         ['rpn_model[0][0]',
#  ate)                                                                'rpn_model[1][0]',
#                                                                      'rpn_model[2][0]',
#                                                                      'rpn_model[3][0]',
#                                                                      'rpn_model[4][0]']
#
#  mrcnn_class_logits (TimeDi  (4, None, 4)                 4100      ['pool_squeeze[0][0]']
#  stributed)
#
#  mrcnn_bbox (Reshape)        (4, None, 4, 4)              0         ['mrcnn_bbox_fc[0][0]']
#
#  mrcnn_mask (TimeDistribute  (4, None, 28, 28, 4)         1028      ['mrcnn_mask_deconv[0][0]']
#  d)
#
#  lambda_5 (Lambda)           (None, 4)                    0         ['input_image_meta[0][0]']
#
# ==================================================================================================
# Total params: 84314206 (321.63 MB)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 84314206 (321.63 MB)
# __________________________________________________________________________________________________

# %%
model.train(dataset_train, dataset_train, 
            epochs=EPOCHS[0], 
            augmentations=None, #augmentation, 
            custom_callbacks=[stop_early, warmup_with_reduce_lr_callback, csv_logger_head])
history = model.keras_model.history.history
# Out:
# Starting at epoch 0.
#
# Checkpoint Path: /mnt/c/Users/ChangGeng/Desktop/FAU/Semester 07/Bachelorarbeit/02_Vision_Transformers/SHVIT_Mask_RCNN/logs/60_shapes_shvit20241211T2226/mask_rcnn_60_shapes_shvit_{epoch:04d}.h5
# n workers used: 32
# Epoch 1: Learning rate is 0.000100 (warmup phase).
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# W0000 00:00:1733952397.860304    1180 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -775 } dim { size: -147 } dim { size: -148 } dim { size: 1 } } } inputs { dtype: DT_FLOAT shape { dim { size: -50 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -50 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } value { dtype: DT_INT32 tensor_shape { dim { size: 2 } } int_val: 28 } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA GeForce RTX 4090" frequency: 2520 num_cores: 128 environment { key: "architecture" value: "8.9" } environment { key: "cuda" value: "12000" } environment { key: "cudnn" value: "8800" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 75497472 shared_memory_size_per_multiprocessor: 102400 memory_size: 22500343808 bandwidth: 1008096000 } outputs { dtype: DT_FLOAT shape { dim { size: -50 } dim { size: 28 } dim { size: 28 } dim { size: 1 } } }
# W0000 00:00:1733952397.860459    1180 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -833 } dim { size: -156 } dim { size: -157 } dim { size: 1 } } } inputs { dtype: DT_FLOAT shape { dim { size: -68 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -68 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } value { dtype: DT_INT32 tensor_shape { dim { size: 2 } } int_val: 28 } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA GeForce RTX 4090" frequency: 2520 num_cores: 128 environment { key: "architecture" value: "8.9" } environment { key: "cuda" value: "12000" } environment { key: "cudnn" value: "8800" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 75497472 shared_memory_size_per_multiprocessor: 102400 memory_size: 22500343808 bandwidth: 1008096000 } outputs { dtype: DT_FLOAT shape { dim { size: -68 } dim { size: 28 } dim { size: 28 } dim { size: 1 } } }
# W0000 00:00:1733952397.860511    1180 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -797 } dim { size: -150 } dim { size: -151 } dim { size: 1 } } } inputs { dtype: DT_FLOAT shape { dim { size: -56 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -56 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } value { dtype: DT_INT32 tensor_shape { dim { size: 2 } } int_val: 28 } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA GeForce RTX 4090" frequency: 2520 num_cores: 128 environment { key: "architecture" value: "8.9" } environment { key: "cuda" value: "12000" } environment { key: "cudnn" value: "8800" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 75497472 shared_memory_size_per_multiprocessor: 102400 memory_size: 22500343808 bandwidth: 1008096000 } outputs { dtype: DT_FLOAT shape { dim { size: -56 } dim { size: 28 } dim { size: 28 } dim { size: 1 } } }
# W0000 00:00:1733952397.860553    1180 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -818 } dim { size: -153 } dim { size: -154 } dim { size: 1 } } } inputs { dtype: DT_FLOAT shape { dim { size: -62 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -62 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } value { dtype: DT_INT32 tensor_shape { dim { size: 2 } } int_val: 28 } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA GeForce RTX 4090" frequency: 2520 num_cores: 128 environment { key: "architecture" value: "8.9" } environment { key: "cuda" value: "12000" } environment { key: "cudnn" value: "8800" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 75497472 shared_memory_size_per_multiprocessor: 102400 memory_size: 22500343808 bandwidth: 1008096000 } outputs { dtype: DT_FLOAT shape { dim { size: -62 } dim { size: 28 } dim { size: 28 } dim { size: 1 } } }
# W0000 00:00:1733952397.861515    1180 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -576 } dim { size: -577 } dim { size: -578 } dim { size: 256 } } } inputs { dtype: DT_FLOAT shape { dim { size: -107 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -107 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } value { dtype: DT_INT32 tensor_shape { dim { size: 2 } } int_val: 7 } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA GeForce RTX 4090" frequency: 2520 num_cores: 128 environment { key: "architecture" value: "8.9" } environment { key: "cuda" value: "12000" } environment { key: "cudnn" value: "8800" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 75497472 shared_memory_size_per_multiprocessor: 102400 memory_size: 22500343808 bandwidth: 1008096000 } outputs { dtype: DT_FLOAT shape { dim { size: -107 } dim { size: 7 } dim { size: 7 } dim { size: 256 } } }
# W0000 00:00:1733952397.861562    1180 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -576 } dim { size: -577 } dim { size: -578 } dim { size: 256 } } } inputs { dtype: DT_FLOAT shape { dim { size: -107 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -107 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } value { dtype: DT_INT32 tensor_shape { dim { size: 2 } } int_val: 14 } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA GeForce RTX 4090" frequency: 2520 num_cores: 128 environment { key: "architecture" value: "8.9" } environment { key: "cuda" value: "12000" } environment { key: "cudnn" value: "8800" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 75497472 shared_memory_size_per_multiprocessor: 102400 memory_size: 22500343808 bandwidth: 1008096000 } outputs { dtype: DT_FLOAT shape { dim { size: -107 } dim { size: 14 } dim { size: 14 } dim { size: 256 } } }
# W0000 00:00:1733952397.861599    1180 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -565 } dim { size: -566 } dim { size: -567 } dim { size: 256 } } } inputs { dtype: DT_FLOAT shape { dim { size: -109 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -109 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } value { dtype: DT_INT32 tensor_shape { dim { size: 2 } } int_val: 7 } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA GeForce RTX 4090" frequency: 2520 num_cores: 128 environment { key: "architecture" value: "8.9" } environment { key: "cuda" value: "12000" } environment { key: "cudnn" value: "8800" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 75497472 shared_memory_size_per_multiprocessor: 102400 memory_size: 22500343808 bandwidth: 1008096000 } outputs { dtype: DT_FLOAT shape { dim { size: -109 } dim { size: 7 } dim { size: 7 } dim { size: 256 } } }
# W0000 00:00:1733952397.861632    1180 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -565 } dim { size: -566 } dim { size: -567 } dim { size: 256 } } } inputs { dtype: DT_FLOAT shape { dim { size: -109 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -109 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } value { dtype: DT_INT32 tensor_shape { dim { size: 2 } } int_val: 14 } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA GeForce RTX 4090" frequency: 2520 num_cores: 128 environment { key: "architecture" value: "8.9" } environment { key: "cuda" value: "12000" } environment { key: "cudnn" value: "8800" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 75497472 shared_memory_size_per_multiprocessor: 102400 memory_size: 22500343808 bandwidth: 1008096000 } outputs { dtype: DT_FLOAT shape { dim { size: -109 } dim { size: 14 } dim { size: 14 } dim { size: 256 } } }
# W0000 00:00:1733952397.861663    1180 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -552 } dim { size: -553 } dim { size: -554 } dim { size: 256 } } } inputs { dtype: DT_FLOAT shape { dim { size: -111 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -111 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } value { dtype: DT_INT32 tensor_shape { dim { size: 2 } } int_val: 7 } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA GeForce RTX 4090" frequency: 2520 num_cores: 128 environment { key: "architecture" value: "8.9" } environment { key: "cuda" value: "12000" } environment { key: "cudnn" value: "8800" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 75497472 shared_memory_size_per_multiprocessor: 102400 memory_size: 22500343808 bandwidth: 1008096000 } outputs { dtype: DT_FLOAT shape { dim { size: -111 } dim { size: 7 } dim { size: 7 } dim { size: 256 } } }
# W0000 00:00:1733952397.861694    1180 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -552 } dim { size: -553 } dim { size: -554 } dim { size: 256 } } } inputs { dtype: DT_FLOAT shape { dim { size: -111 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -111 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } value { dtype: DT_INT32 tensor_shape { dim { size: 2 } } int_val: 14 } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA GeForce RTX 4090" frequency: 2520 num_cores: 128 environment { key: "architecture" value: "8.9" } environment { key: "cuda" value: "12000" } environment { key: "cudnn" value: "8800" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 75497472 shared_memory_size_per_multiprocessor: 102400 memory_size: 22500343808 bandwidth: 1008096000 } outputs { dtype: DT_FLOAT shape { dim { size: -111 } dim { size: 14 } dim { size: 14 } dim { size: 256 } } }
# W0000 00:00:1733952397.861736    1180 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -535 } dim { size: -538 } dim { size: -539 } dim { size: 256 } } } inputs { dtype: DT_FLOAT shape { dim { size: -113 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -113 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } value { dtype: DT_INT32 tensor_shape { dim { size: 2 } } int_val: 7 } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA GeForce RTX 4090" frequency: 2520 num_cores: 128 environment { key: "architecture" value: "8.9" } environment { key: "cuda" value: "12000" } environment { key: "cudnn" value: "8800" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 75497472 shared_memory_size_per_multiprocessor: 102400 memory_size: 22500343808 bandwidth: 1008096000 } outputs { dtype: DT_FLOAT shape { dim { size: -113 } dim { size: 7 } dim { size: 7 } dim { size: 256 } } }
# W0000 00:00:1733952397.861768    1180 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -535 } dim { size: -538 } dim { size: -539 } dim { size: 256 } } } inputs { dtype: DT_FLOAT shape { dim { size: -113 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -113 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } value { dtype: DT_INT32 tensor_shape { dim { size: 2 } } int_val: 14 } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA GeForce RTX 4090" frequency: 2520 num_cores: 128 environment { key: "architecture" value: "8.9" } environment { key: "cuda" value: "12000" } environment { key: "cudnn" value: "8800" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 75497472 shared_memory_size_per_multiprocessor: 102400 memory_size: 22500343808 bandwidth: 1008096000 } outputs { dtype: DT_FLOAT shape { dim { size: -113 } dim { size: 14 } dim { size: 14 } dim { size: 256 } } }
# 2500/2500 [==============================] - ETA: 0s - loss: 7690762.5000 - rpn_class_loss: 855266.3750 - rpn_bbox_loss: 4839349.0000 - mrcnn_class_loss: 1994303.6683 - mrcnn_bbox_loss: 0.0000e+00 - mrcnn_mask_loss: 0.0000e+00
# W0000 00:00:1733952575.252768    1180 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -775 } dim { size: -147 } dim { size: -148 } dim { size: 1 } } } inputs { dtype: DT_FLOAT shape { dim { size: -50 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -50 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } value { dtype: DT_INT32 tensor_shape { dim { size: 2 } } int_val: 28 } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA GeForce RTX 4090" frequency: 2520 num_cores: 128 environment { key: "architecture" value: "8.9" } environment { key: "cuda" value: "12000" } environment { key: "cudnn" value: "8800" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 75497472 shared_memory_size_per_multiprocessor: 102400 memory_size: 22500343808 bandwidth: 1008096000 } outputs { dtype: DT_FLOAT shape { dim { size: -50 } dim { size: 28 } dim { size: 28 } dim { size: 1 } } }
# W0000 00:00:1733952575.252901    1180 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -833 } dim { size: -156 } dim { size: -157 } dim { size: 1 } } } inputs { dtype: DT_FLOAT shape { dim { size: -68 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -68 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } value { dtype: DT_INT32 tensor_shape { dim { size: 2 } } int_val: 28 } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA GeForce RTX 4090" frequency: 2520 num_cores: 128 environment { key: "architecture" value: "8.9" } environment { key: "cuda" value: "12000" } environment { key: "cudnn" value: "8800" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 75497472 shared_memory_size_per_multiprocessor: 102400 memory_size: 22500343808 bandwidth: 1008096000 } outputs { dtype: DT_FLOAT shape { dim { size: -68 } dim { size: 28 } dim { size: 28 } dim { size: 1 } } }
# W0000 00:00:1733952575.252957    1180 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -797 } dim { size: -150 } dim { size: -151 } dim { size: 1 } } } inputs { dtype: DT_FLOAT shape { dim { size: -56 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -56 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } value { dtype: DT_INT32 tensor_shape { dim { size: 2 } } int_val: 28 } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA GeForce RTX 4090" frequency: 2520 num_cores: 128 environment { key: "architecture" value: "8.9" } environment { key: "cuda" value: "12000" } environment { key: "cudnn" value: "8800" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 75497472 shared_memory_size_per_multiprocessor: 102400 memory_size: 22500343808 bandwidth: 1008096000 } outputs { dtype: DT_FLOAT shape { dim { size: -56 } dim { size: 28 } dim { size: 28 } dim { size: 1 } } }
# W0000 00:00:1733952575.253002    1180 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -818 } dim { size: -153 } dim { size: -154 } dim { size: 1 } } } inputs { dtype: DT_FLOAT shape { dim { size: -62 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -62 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } value { dtype: DT_INT32 tensor_shape { dim { size: 2 } } int_val: 28 } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA GeForce RTX 4090" frequency: 2520 num_cores: 128 environment { key: "architecture" value: "8.9" } environment { key: "cuda" value: "12000" } environment { key: "cudnn" value: "8800" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 75497472 shared_memory_size_per_multiprocessor: 102400 memory_size: 22500343808 bandwidth: 1008096000 } outputs { dtype: DT_FLOAT shape { dim { size: -62 } dim { size: 28 } dim { size: 28 } dim { size: 1 } } }
# W0000 00:00:1733952575.254005    1180 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -576 } dim { size: -577 } dim { size: -578 } dim { size: 256 } } } inputs { dtype: DT_FLOAT shape { dim { size: -107 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -107 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } value { dtype: DT_INT32 tensor_shape { dim { size: 2 } } int_val: 7 } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA GeForce RTX 4090" frequency: 2520 num_cores: 128 environment { key: "architecture" value: "8.9" } environment { key: "cuda" value: "12000" } environment { key: "cudnn" value: "8800" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 75497472 shared_memory_size_per_multiprocessor: 102400 memory_size: 22500343808 bandwidth: 1008096000 } outputs { dtype: DT_FLOAT shape { dim { size: -107 } dim { size: 7 } dim { size: 7 } dim { size: 256 } } }
# W0000 00:00:1733952575.254048    1180 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -576 } dim { size: -577 } dim { size: -578 } dim { size: 256 } } } inputs { dtype: DT_FLOAT shape { dim { size: -107 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -107 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } value { dtype: DT_INT32 tensor_shape { dim { size: 2 } } int_val: 14 } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA GeForce RTX 4090" frequency: 2520 num_cores: 128 environment { key: "architecture" value: "8.9" } environment { key: "cuda" value: "12000" } environment { key: "cudnn" value: "8800" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 75497472 shared_memory_size_per_multiprocessor: 102400 memory_size: 22500343808 bandwidth: 1008096000 } outputs { dtype: DT_FLOAT shape { dim { size: -107 } dim { size: 14 } dim { size: 14 } dim { size: 256 } } }
# W0000 00:00:1733952575.254074    1180 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -565 } dim { size: -566 } dim { size: -567 } dim { size: 256 } } } inputs { dtype: DT_FLOAT shape { dim { size: -109 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -109 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } value { dtype: DT_INT32 tensor_shape { dim { size: 2 } } int_val: 7 } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA GeForce RTX 4090" frequency: 2520 num_cores: 128 environment { key: "architecture" value: "8.9" } environment { key: "cuda" value: "12000" } environment { key: "cudnn" value: "8800" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 75497472 shared_memory_size_per_multiprocessor: 102400 memory_size: 22500343808 bandwidth: 1008096000 } outputs { dtype: DT_FLOAT shape { dim { size: -109 } dim { size: 7 } dim { size: 7 } dim { size: 256 } } }
# W0000 00:00:1733952575.254093    1180 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -565 } dim { size: -566 } dim { size: -567 } dim { size: 256 } } } inputs { dtype: DT_FLOAT shape { dim { size: -109 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -109 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } value { dtype: DT_INT32 tensor_shape { dim { size: 2 } } int_val: 14 } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA GeForce RTX 4090" frequency: 2520 num_cores: 128 environment { key: "architecture" value: "8.9" } environment { key: "cuda" value: "12000" } environment { key: "cudnn" value: "8800" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 75497472 shared_memory_size_per_multiprocessor: 102400 memory_size: 22500343808 bandwidth: 1008096000 } outputs { dtype: DT_FLOAT shape { dim { size: -109 } dim { size: 14 } dim { size: 14 } dim { size: 256 } } }
# W0000 00:00:1733952575.254124    1180 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -552 } dim { size: -553 } dim { size: -554 } dim { size: 256 } } } inputs { dtype: DT_FLOAT shape { dim { size: -111 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -111 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } value { dtype: DT_INT32 tensor_shape { dim { size: 2 } } int_val: 7 } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA GeForce RTX 4090" frequency: 2520 num_cores: 128 environment { key: "architecture" value: "8.9" } environment { key: "cuda" value: "12000" } environment { key: "cudnn" value: "8800" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 75497472 shared_memory_size_per_multiprocessor: 102400 memory_size: 22500343808 bandwidth: 1008096000 } outputs { dtype: DT_FLOAT shape { dim { size: -111 } dim { size: 7 } dim { size: 7 } dim { size: 256 } } }
# W0000 00:00:1733952575.254145    1180 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -552 } dim { size: -553 } dim { size: -554 } dim { size: 256 } } } inputs { dtype: DT_FLOAT shape { dim { size: -111 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -111 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } value { dtype: DT_INT32 tensor_shape { dim { size: 2 } } int_val: 14 } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA GeForce RTX 4090" frequency: 2520 num_cores: 128 environment { key: "architecture" value: "8.9" } environment { key: "cuda" value: "12000" } environment { key: "cudnn" value: "8800" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 75497472 shared_memory_size_per_multiprocessor: 102400 memory_size: 22500343808 bandwidth: 1008096000 } outputs { dtype: DT_FLOAT shape { dim { size: -111 } dim { size: 14 } dim { size: 14 } dim { size: 256 } } }
# W0000 00:00:1733952575.254182    1180 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -535 } dim { size: -538 } dim { size: -539 } dim { size: 256 } } } inputs { dtype: DT_FLOAT shape { dim { size: -113 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -113 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } value { dtype: DT_INT32 tensor_shape { dim { size: 2 } } int_val: 7 } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA GeForce RTX 4090" frequency: 2520 num_cores: 128 environment { key: "architecture" value: "8.9" } environment { key: "cuda" value: "12000" } environment { key: "cudnn" value: "8800" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 75497472 shared_memory_size_per_multiprocessor: 102400 memory_size: 22500343808 bandwidth: 1008096000 } outputs { dtype: DT_FLOAT shape { dim { size: -113 } dim { size: 7 } dim { size: 7 } dim { size: 256 } } }
# W0000 00:00:1733952575.254217    1180 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -535 } dim { size: -538 } dim { size: -539 } dim { size: 256 } } } inputs { dtype: DT_FLOAT shape { dim { size: -113 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -113 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } value { dtype: DT_INT32 tensor_shape { dim { size: 2 } } int_val: 14 } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA GeForce RTX 4090" frequency: 2520 num_cores: 128 environment { key: "architecture" value: "8.9" } environment { key: "cuda" value: "12000" } environment { key: "cudnn" value: "8800" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 75497472 shared_memory_size_per_multiprocessor: 102400 memory_size: 22500343808 bandwidth: 1008096000 } outputs { dtype: DT_FLOAT shape { dim { size: -113 } dim { size: 14 } dim { size: 14 } dim { size: 256 } } }
# 2500/2500 [==============================] - 199s 77ms/step - loss: 7690762.5000 - rpn_class_loss: 855266.3750 - rpn_bbox_loss: 4839349.0000 - mrcnn_class_loss: 1994304.4084 - mrcnn_bbox_loss: 0.0000e+00 - mrcnn_mask_loss: 0.0000e+00 - val_loss: 7754297.5000 - val_rpn_class_loss: 859758.4375 - val_rpn_bbox_loss: 4884944.5000 - val_mrcnn_class_loss: 2009595.6250 - val_mrcnn_bbox_loss: 0.0000e+00 - val_mrcnn_mask_loss: 0.0000e+00

# %%
model.compile(layers="all")
model.summary()
# Out:
# Selecting layers to train
# conv2d_bn              (Conv2d_BN)
# conv2d_bn_1            (Conv2d_BN)
# conv2d_bn_2            (Conv2d_BN)
# conv2d_bn_3            (Conv2d_BN)
# blocks1_i              (Sequential)
# blocks2_s              (Sequential)
# blocks3_s              (Sequential)
# fpn_c5p5               (Conv2D)
# fpn_c4p4               (Conv2D)
# fpn_c3p3               (Conv2D)
# fpn_c2p2               (Conv2D)
# fpn_p5                 (Conv2D)
# fpn_p2                 (Conv2D)
# fpn_p3                 (Conv2D)
# fpn_p4                 (Conv2D)
# rpn_model              (Functional)
# anchors                (ConstLayer)
# mrcnn_mask_conv1       (TimeDistributed)
# mrcnn_mask_bn1         (TimeDistributed)
# mrcnn_mask_conv2       (TimeDistributed)
# mrcnn_mask_bn2         (TimeDistributed)
# mrcnn_class_conv1      (TimeDistributed)
# mrcnn_class_bn1        (TimeDistributed)
# mrcnn_mask_conv3       (TimeDistributed)
# mrcnn_mask_bn3         (TimeDistributed)
# mrcnn_class_conv2      (TimeDistributed)
# mrcnn_class_bn2        (TimeDistributed)
# mrcnn_mask_conv4       (TimeDistributed)
# mrcnn_mask_bn4         (TimeDistributed)
# mrcnn_bbox_fc          (TimeDistributed)
# mrcnn_mask_deconv      (TimeDistributed)
# mrcnn_class_logits     (TimeDistributed)
# mrcnn_mask             (TimeDistributed)
# Model: "mask_rcnn"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_image (InputLayer)    [(None, None, None, 3)]      0         []
#
#  conv2d_bn (Conv2d_BN)       (None, None, None, 28)       868       ['input_image[0][0]']
#
#  conv2d_bn_1 (Conv2d_BN)     (None, None, None, 56)       14336     ['conv2d_bn[0][0]']
#
#  conv2d_bn_2 (Conv2d_BN)     (None, None, None, 112)      56896     ['conv2d_bn_1[0][0]']
#
#  conv2d_bn_3 (Conv2d_BN)     (None, None, None, 224)      226688    ['conv2d_bn_2[0][0]']
#
#  blocks1_i (Sequential)      (None, None, None, 224)      2623488   ['conv2d_bn_3[0][0]']
#
#  blocks2_s (Sequential)      (None, None, None, 336)      2143321   ['blocks1_i[0][0]']
#                                                           6
#
#  blocks3_s (Sequential)      (None, None, None, 448)      3930715   ['blocks2_s[0][0]']
#                                                           2
#
#  fpn_c5p5 (Conv2D)           (None, None, None, 256)      114944    ['blocks3_s[0][0]']
#
#  fpn_p5upsampled (UpSamplin  (None, None, None, 256)      0         ['fpn_c5p5[0][0]']
#  g2D)
#
#  fpn_c4p4 (Conv2D)           (None, None, None, 256)      86272     ['blocks2_s[0][0]']
#
#  fpn_p4add (Add)             (None, None, None, 256)      0         ['fpn_p5upsampled[0][0]',
#                                                                      'fpn_c4p4[0][0]']
#
#  fpn_p4upsampled (UpSamplin  (None, None, None, 256)      0         ['fpn_p4add[0][0]']
#  g2D)
#
#  fpn_c3p3 (Conv2D)           (None, None, None, 256)      57600     ['blocks1_i[0][0]']
#
#  fpn_p3add (Add)             (None, None, None, 256)      0         ['fpn_p4upsampled[0][0]',
#                                                                      'fpn_c3p3[0][0]']
#
#  fpn_p3upsampled (UpSamplin  (None, None, None, 256)      0         ['fpn_p3add[0][0]']
#  g2D)
#
#  fpn_c2p2 (Conv2D)           (None, None, None, 256)      28928     ['conv2d_bn_2[0][0]']
#
#  fpn_p2add (Add)             (None, None, None, 256)      0         ['fpn_p3upsampled[0][0]',
#                                                                      'fpn_c2p2[0][0]']
#
#  fpn_p5 (Conv2D)             (None, None, None, 256)      590080    ['fpn_c5p5[0][0]']
#
#  fpn_p2 (Conv2D)             (None, None, None, 256)      590080    ['fpn_p2add[0][0]']
#
#  fpn_p3 (Conv2D)             (None, None, None, 256)      590080    ['fpn_p3add[0][0]']
#
#  fpn_p4 (Conv2D)             (None, None, None, 256)      590080    ['fpn_p4add[0][0]']
#
#  fpn_p6 (MaxPooling2D)       (None, None, None, 256)      0         ['fpn_p5[0][0]']
#
#  rpn_model (Functional)      [(None, None, 2),            1189394   ['fpn_p2[0][0]',
#                               (None, None, 2),                       'fpn_p3[0][0]',
#                               (None, None, 4)]                       'fpn_p4[0][0]',
#                                                                      'fpn_p5[0][0]',
#                                                                      'fpn_p6[0][0]']
#
#  rpn_bbox (Concatenate)      (None, None, 4)              0         ['rpn_model[0][2]',
#                                                                      'rpn_model[1][2]',
#                                                                      'rpn_model[2][2]',
#                                                                      'rpn_model[3][2]',
#                                                                      'rpn_model[4][2]']
#
#  rpn_class (Concatenate)     (None, None, 2)              0         ['rpn_model[0][1]',
#                                                                      'rpn_model[1][1]',
#                                                                      'rpn_model[2][1]',
#                                                                      'rpn_model[3][1]',
#                                                                      'rpn_model[4][1]']
#
#  anchors (ConstLayer)        (4, 16368, 4)                261888    ['input_image[0][0]']
#
#  input_gt_boxes (InputLayer  [(None, None, 4)]            0         []
#  )
#
#  ROI (ProposalLayer)         (4, 2000, 4)                 0         ['rpn_class[0][0]',
#                                                                      'rpn_bbox[0][0]',
#                                                                      'anchors[0][0]']
#
#  input_gt_class_ids (InputL  [(None, None)]               0         []
#  ayer)
#
#  lambda (Lambda)             (None, None, 4)              0         ['input_gt_boxes[0][0]',
#                                                                      'input_image[0][0]']
#
#  input_gt_masks (InputLayer  [(None, 512, 512, None)]     0         []
#  )
#
#  proposal_targets (Detectio  [(4, None, 4),               0         ['ROI[0][0]',
#  nTargetLayer)                (4, None),                             'input_gt_class_ids[0][0]',
#                               (4, None, 4),                          'lambda[0][0]',
#                               (4, None, 28, 28)]                     'input_gt_masks[0][0]']
#
#  input_image_meta (InputLay  [(None, 16)]                 0         []
#  er)
#
#  roi_align_mask (PyramidROI  (4, None, 14, 14, 256)       0         ['proposal_targets[0][0]',
#  Align)                                                              'input_image_meta[0][0]',
#                                                                      'fpn_p2[0][0]',
#                                                                      'fpn_p3[0][0]',
#                                                                      'fpn_p4[0][0]',
#                                                                      'fpn_p5[0][0]']
#
#  mrcnn_mask_conv1 (TimeDist  (4, None, 14, 14, 256)       590080    ['roi_align_mask[0][0]']
#  ributed)
#
#  mrcnn_mask_bn1 (TimeDistri  (4, None, 14, 14, 256)       1024      ['mrcnn_mask_conv1[0][0]']
#  buted)
#
#  activation_106 (Activation  (4, None, 14, 14, 256)       0         ['mrcnn_mask_bn1[0][0]']
#  )
#
#  mrcnn_mask_conv2 (TimeDist  (4, None, 14, 14, 256)       590080    ['activation_106[0][0]']
#  ributed)
#
#  roi_align_classifier (Pyra  (4, None, 7, 7, 256)         0         ['proposal_targets[0][0]',
#  midROIAlign)                                                        'input_image_meta[0][0]',
#                                                                      'fpn_p2[0][0]',
#                                                                      'fpn_p3[0][0]',
#                                                                      'fpn_p4[0][0]',
#                                                                      'fpn_p5[0][0]']
#
#  mrcnn_mask_bn2 (TimeDistri  (4, None, 14, 14, 256)       1024      ['mrcnn_mask_conv2[0][0]']
#  buted)
#
#  mrcnn_class_conv1 (TimeDis  (4, None, 1, 1, 1024)        1284608   ['roi_align_classifier[0][0]']
#  tributed)                                                0
#
#  activation_107 (Activation  (4, None, 14, 14, 256)       0         ['mrcnn_mask_bn2[0][0]']
#  )
#
#  mrcnn_class_bn1 (TimeDistr  (4, None, 1, 1, 1024)        4096      ['mrcnn_class_conv1[0][0]']
#  ibuted)
#
#  mrcnn_mask_conv3 (TimeDist  (4, None, 14, 14, 256)       590080    ['activation_107[0][0]']
#  ributed)
#
#  activation_103 (Activation  (4, None, 1, 1, 1024)        0         ['mrcnn_class_bn1[0][0]']
#  )
#
#  mrcnn_mask_bn3 (TimeDistri  (4, None, 14, 14, 256)       1024      ['mrcnn_mask_conv3[0][0]']
#  buted)
#
#  mrcnn_class_conv2 (TimeDis  (4, None, 1, 1, 1024)        1049600   ['activation_103[0][0]']
#  tributed)
#
#  activation_108 (Activation  (4, None, 14, 14, 256)       0         ['mrcnn_mask_bn3[0][0]']
#  )
#
#  mrcnn_class_bn2 (TimeDistr  (4, None, 1, 1, 1024)        4096      ['mrcnn_class_conv2[0][0]']
#  ibuted)
#
#  mrcnn_mask_conv4 (TimeDist  (4, None, 14, 14, 256)       590080    ['activation_108[0][0]']
#  ributed)
#
#  activation_104 (Activation  (4, None, 1, 1, 1024)        0         ['mrcnn_class_bn2[0][0]']
#  )
#
#  mrcnn_mask_bn4 (TimeDistri  (4, None, 14, 14, 256)       1024      ['mrcnn_mask_conv4[0][0]']
#  buted)
#
#  pool_squeeze (Lambda)       (4, None, 1024)              0         ['activation_104[0][0]']
#
#  activation_109 (Activation  (4, None, 14, 14, 256)       0         ['mrcnn_mask_bn4[0][0]']
#  )
#
#  mrcnn_bbox_fc (TimeDistrib  (4, None, 16)                16400     ['pool_squeeze[0][0]']
#  uted)
#
#  mrcnn_mask_deconv (TimeDis  (4, None, 28, 28, 256)       262400    ['activation_109[0][0]']
#  tributed)
#
#  input_rpn_match (InputLaye  [(None, None, 1)]            0         []
#  r)
#
#  input_rpn_bbox (InputLayer  [(None, None, 4)]            0         []
#  )
#
#  rpn_class_logits (Concaten  (None, None, 2)              0         ['rpn_model[0][0]',
#  ate)                                                                'rpn_model[1][0]',
#                                                                      'rpn_model[2][0]',
#                                                                      'rpn_model[3][0]',
#                                                                      'rpn_model[4][0]']
#
#  mrcnn_class_logits (TimeDi  (4, None, 4)                 4100      ['pool_squeeze[0][0]']
#  stributed)
#
#  mrcnn_bbox (Reshape)        (4, None, 4, 4)              0         ['mrcnn_bbox_fc[0][0]']
#
#  mrcnn_mask (TimeDistribute  (4, None, 28, 28, 4)         1028      ['mrcnn_mask_deconv[0][0]']
#  d)
#
#  lambda_5 (Lambda)           (None, 4)                    0         ['input_image_meta[0][0]']
#
# ==================================================================================================
# Total params: 84314206 (321.63 MB)
# Trainable params: 83963494 (320.30 MB)
# Non-trainable params: 350712 (1.34 MB)
# __________________________________________________________________________________________________

# %%
model.train(dataset_train, dataset_train, 
            epochs=EPOCHS[2], # try EPOCHS[1] (500) -> for now EPOCHS[2], which is 200
            augmentations=None, #augmentation,  
            custom_callbacks=[stop_early, warmup_with_reduce_lr_callback, csv_logger_all])
new_history = model.keras_model.history.history
for k in new_history: 
    history[k] = history[k] + new_history[k]
# Out:
# Starting at epoch 1.
#
# Checkpoint Path: /mnt/c/Users/ChangGeng/Desktop/FAU/Semester 07/Bachelorarbeit/02_Vision_Transformers/SHVIT_Mask_RCNN/logs/60_shapes_shvit20241211T2226/mask_rcnn_60_shapes_shvit_{epoch:04d}.h5
# n workers used: 32
# Epoch 2: Learning rate is 0.000200 (warmup phase).
# Epoch 2/200
# W0000 00:00:1733952610.104705    1180 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -1390 } dim { size: -826 } dim { size: -827 } dim { size: 1 } } } inputs { dtype: DT_FLOAT shape { dim { size: -67 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -67 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } value { dtype: DT_INT32 tensor_shape { dim { size: 2 } } int_val: 28 } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA GeForce RTX 4090" frequency: 2520 num_cores: 128 environment { key: "architecture" value: "8.9" } environment { key: "cuda" value: "12000" } environment { key: "cudnn" value: "8800" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 75497472 shared_memory_size_per_multiprocessor: 102400 memory_size: 22500343808 bandwidth: 1008096000 } outputs { dtype: DT_FLOAT shape { dim { size: -67 } dim { size: 28 } dim { size: 28 } dim { size: 1 } } }
# W0000 00:00:1733952610.104851    1180 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -1506 } dim { size: -835 } dim { size: -836 } dim { size: 1 } } } inputs { dtype: DT_FLOAT shape { dim { size: -85 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -85 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } value { dtype: DT_INT32 tensor_shape { dim { size: 2 } } int_val: 28 } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA GeForce RTX 4090" frequency: 2520 num_cores: 128 environment { key: "architecture" value: "8.9" } environment { key: "cuda" value: "12000" } environment { key: "cudnn" value: "8800" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 75497472 shared_memory_size_per_multiprocessor: 102400 memory_size: 22500343808 bandwidth: 1008096000 } outputs { dtype: DT_FLOAT shape { dim { size: -85 } dim { size: 28 } dim { size: 28 } dim { size: 1 } } }
# W0000 00:00:1733952610.104929    1180 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -1420 } dim { size: -829 } dim { size: -830 } dim { size: 1 } } } inputs { dtype: DT_FLOAT shape { dim { size: -73 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -73 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } value { dtype: DT_INT32 tensor_shape { dim { size: 2 } } int_val: 28 } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA GeForce RTX 4090" frequency: 2520 num_cores: 128 environment { key: "architecture" value: "8.9" } environment { key: "cuda" value: "12000" } environment { key: "cudnn" value: "8800" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 75497472 shared_memory_size_per_multiprocessor: 102400 memory_size: 22500343808 bandwidth: 1008096000 } outputs { dtype: DT_FLOAT shape { dim { size: -73 } dim { size: 28 } dim { size: 28 } dim { size: 1 } } }
# W0000 00:00:1733952610.104998    1180 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -1467 } dim { size: -832 } dim { size: -833 } dim { size: 1 } } } inputs { dtype: DT_FLOAT shape { dim { size: -79 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -79 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } value { dtype: DT_INT32 tensor_shape { dim { size: 2 } } int_val: 28 } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA GeForce RTX 4090" frequency: 2520 num_cores: 128 environment { key: "architecture" value: "8.9" } environment { key: "cuda" value: "12000" } environment { key: "cudnn" value: "8800" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 75497472 shared_memory_size_per_multiprocessor: 102400 memory_size: 22500343808 bandwidth: 1008096000 } outputs { dtype: DT_FLOAT shape { dim { size: -79 } dim { size: 28 } dim { size: 28 } dim { size: 1 } } }
# W0000 00:00:1733952610.106534    1180 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -44 } dim { size: -260 } dim { size: -261 } dim { size: 256 } } } inputs { dtype: DT_FLOAT shape { dim { size: -124 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -124 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } value { dtype: DT_INT32 tensor_shape { dim { size: 2 } } int_val: 7 } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA GeForce RTX 4090" frequency: 2520 num_cores: 128 environment { key: "architecture" value: "8.9" } environment { key: "cuda" value: "12000" } environment { key: "cudnn" value: "8800" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 75497472 shared_memory_size_per_multiprocessor: 102400 memory_size: 22500343808 bandwidth: 1008096000 } outputs { dtype: DT_FLOAT shape { dim { size: -124 } dim { size: 7 } dim { size: 7 } dim { size: 256 } } }
# W0000 00:00:1733952610.106580    1180 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -44 } dim { size: -260 } dim { size: -261 } dim { size: 256 } } } inputs { dtype: DT_FLOAT shape { dim { size: -124 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -124 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } value { dtype: DT_INT32 tensor_shape { dim { size: 2 } } int_val: 14 } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA GeForce RTX 4090" frequency: 2520 num_cores: 128 environment { key: "architecture" value: "8.9" } environment { key: "cuda" value: "12000" } environment { key: "cudnn" value: "8800" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 75497472 shared_memory_size_per_multiprocessor: 102400 memory_size: 22500343808 bandwidth: 1008096000 } outputs { dtype: DT_FLOAT shape { dim { size: -124 } dim { size: 14 } dim { size: 14 } dim { size: 256 } } }
# W0000 00:00:1733952610.106605    1180 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -47 } dim { size: -268 } dim { size: -269 } dim { size: 256 } } } inputs { dtype: DT_FLOAT shape { dim { size: -126 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -126 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } value { dtype: DT_INT32 tensor_shape { dim { size: 2 } } int_val: 7 } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA GeForce RTX 4090" frequency: 2520 num_cores: 128 environment { key: "architecture" value: "8.9" } environment { key: "cuda" value: "12000" } environment { key: "cudnn" value: "8800" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 75497472 shared_memory_size_per_multiprocessor: 102400 memory_size: 22500343808 bandwidth: 1008096000 } outputs { dtype: DT_FLOAT shape { dim { size: -126 } dim { size: 7 } dim { size: 7 } dim { size: 256 } } }
# W0000 00:00:1733952610.106635    1180 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -47 } dim { size: -268 } dim { size: -269 } dim { size: 256 } } } inputs { dtype: DT_FLOAT shape { dim { size: -126 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -126 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } value { dtype: DT_INT32 tensor_shape { dim { size: 2 } } int_val: 14 } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA GeForce RTX 4090" frequency: 2520 num_cores: 128 environment { key: "architecture" value: "8.9" } environment { key: "cuda" value: "12000" } environment { key: "cudnn" value: "8800" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 75497472 shared_memory_size_per_multiprocessor: 102400 memory_size: 22500343808 bandwidth: 1008096000 } outputs { dtype: DT_FLOAT shape { dim { size: -126 } dim { size: 14 } dim { size: 14 } dim { size: 256 } } }
# W0000 00:00:1733952610.106668    1180 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -50 } dim { size: -276 } dim { size: -277 } dim { size: 256 } } } inputs { dtype: DT_FLOAT shape { dim { size: -128 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -128 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } value { dtype: DT_INT32 tensor_shape { dim { size: 2 } } int_val: 7 } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA GeForce RTX 4090" frequency: 2520 num_cores: 128 environment { key: "architecture" value: "8.9" } environment { key: "cuda" value: "12000" } environment { key: "cudnn" value: "8800" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 75497472 shared_memory_size_per_multiprocessor: 102400 memory_size: 22500343808 bandwidth: 1008096000 } outputs { dtype: DT_FLOAT shape { dim { size: -128 } dim { size: 7 } dim { size: 7 } dim { size: 256 } } }
# W0000 00:00:1733952610.106698    1180 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -50 } dim { size: -276 } dim { size: -277 } dim { size: 256 } } } inputs { dtype: DT_FLOAT shape { dim { size: -128 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -128 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } value { dtype: DT_INT32 tensor_shape { dim { size: 2 } } int_val: 14 } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA GeForce RTX 4090" frequency: 2520 num_cores: 128 environment { key: "architecture" value: "8.9" } environment { key: "cuda" value: "12000" } environment { key: "cudnn" value: "8800" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 75497472 shared_memory_size_per_multiprocessor: 102400 memory_size: 22500343808 bandwidth: 1008096000 } outputs { dtype: DT_FLOAT shape { dim { size: -128 } dim { size: 14 } dim { size: 14 } dim { size: 256 } } }
# W0000 00:00:1733952610.106736    1180 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -53 } dim { size: -252 } dim { size: -253 } dim { size: 256 } } } inputs { dtype: DT_FLOAT shape { dim { size: -130 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -130 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } value { dtype: DT_INT32 tensor_shape { dim { size: 2 } } int_val: 7 } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA GeForce RTX 4090" frequency: 2520 num_cores: 128 environment { key: "architecture" value: "8.9" } environment { key: "cuda" value: "12000" } environment { key: "cudnn" value: "8800" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 75497472 shared_memory_size_per_multiprocessor: 102400 memory_size: 22500343808 bandwidth: 1008096000 } outputs { dtype: DT_FLOAT shape { dim { size: -130 } dim { size: 7 } dim { size: 7 } dim { size: 256 } } }
# W0000 00:00:1733952610.106769    1180 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -53 } dim { size: -252 } dim { size: -253 } dim { size: 256 } } } inputs { dtype: DT_FLOAT shape { dim { size: -130 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -130 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } value { dtype: DT_INT32 tensor_shape { dim { size: 2 } } int_val: 14 } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA GeForce RTX 4090" frequency: 2520 num_cores: 128 environment { key: "architecture" value: "8.9" } environment { key: "cuda" value: "12000" } environment { key: "cudnn" value: "8800" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 75497472 shared_memory_size_per_multiprocessor: 102400 memory_size: 22500343808 bandwidth: 1008096000 } outputs { dtype: DT_FLOAT shape { dim { size: -130 } dim { size: 14 } dim { size: 14 } dim { size: 256 } } }
# I0000 00:00:1733952613.036788    1323 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2500/2500 [==============================] - ETA: 0s - loss: 2.4508 - rpn_class_loss: 0.0378 - rpn_bbox_loss: 1.1352 - mrcnn_class_loss: 0.3176 - mrcnn_bbox_loss: 0.9148 - mrcnn_mask_loss: 0.5293
# W0000 00:00:1733953075.239898    1180 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -775 } dim { size: -147 } dim { size: -148 } dim { size: 1 } } } inputs { dtype: DT_FLOAT shape { dim { size: -50 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -50 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } value { dtype: DT_INT32 tensor_shape { dim { size: 2 } } int_val: 28 } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA GeForce RTX 4090" frequency: 2520 num_cores: 128 environment { key: "architecture" value: "8.9" } environment { key: "cuda" value: "12000" } environment { key: "cudnn" value: "8800" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 75497472 shared_memory_size_per_multiprocessor: 102400 memory_size: 22500343808 bandwidth: 1008096000 } outputs { dtype: DT_FLOAT shape { dim { size: -50 } dim { size: 28 } dim { size: 28 } dim { size: 1 } } }
# W0000 00:00:1733953075.240019    1180 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -833 } dim { size: -156 } dim { size: -157 } dim { size: 1 } } } inputs { dtype: DT_FLOAT shape { dim { size: -68 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -68 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } value { dtype: DT_INT32 tensor_shape { dim { size: 2 } } int_val: 28 } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA GeForce RTX 4090" frequency: 2520 num_cores: 128 environment { key: "architecture" value: "8.9" } environment { key: "cuda" value: "12000" } environment { key: "cudnn" value: "8800" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 75497472 shared_memory_size_per_multiprocessor: 102400 memory_size: 22500343808 bandwidth: 1008096000 } outputs { dtype: DT_FLOAT shape { dim { size: -68 } dim { size: 28 } dim { size: 28 } dim { size: 1 } } }
# W0000 00:00:1733953075.240068    1180 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -797 } dim { size: -150 } dim { size: -151 } dim { size: 1 } } } inputs { dtype: DT_FLOAT shape { dim { size: -56 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -56 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } value { dtype: DT_INT32 tensor_shape { dim { size: 2 } } int_val: 28 } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA GeForce RTX 4090" frequency: 2520 num_cores: 128 environment { key: "architecture" value: "8.9" } environment { key: "cuda" value: "12000" } environment { key: "cudnn" value: "8800" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 75497472 shared_memory_size_per_multiprocessor: 102400 memory_size: 22500343808 bandwidth: 1008096000 } outputs { dtype: DT_FLOAT shape { dim { size: -56 } dim { size: 28 } dim { size: 28 } dim { size: 1 } } }
# W0000 00:00:1733953075.240109    1180 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -818 } dim { size: -153 } dim { size: -154 } dim { size: 1 } } } inputs { dtype: DT_FLOAT shape { dim { size: -62 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -62 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } value { dtype: DT_INT32 tensor_shape { dim { size: 2 } } int_val: 28 } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA GeForce RTX 4090" frequency: 2520 num_cores: 128 environment { key: "architecture" value: "8.9" } environment { key: "cuda" value: "12000" } environment { key: "cudnn" value: "8800" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 75497472 shared_memory_size_per_multiprocessor: 102400 memory_size: 22500343808 bandwidth: 1008096000 } outputs { dtype: DT_FLOAT shape { dim { size: -62 } dim { size: 28 } dim { size: 28 } dim { size: 1 } } }
# W0000 00:00:1733953075.240995    1180 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -576 } dim { size: -577 } dim { size: -578 } dim { size: 256 } } } inputs { dtype: DT_FLOAT shape { dim { size: -107 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -107 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } value { dtype: DT_INT32 tensor_shape { dim { size: 2 } } int_val: 7 } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA GeForce RTX 4090" frequency: 2520 num_cores: 128 environment { key: "architecture" value: "8.9" } environment { key: "cuda" value: "12000" } environment { key: "cudnn" value: "8800" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 75497472 shared_memory_size_per_multiprocessor: 102400 memory_size: 22500343808 bandwidth: 1008096000 } outputs { dtype: DT_FLOAT shape { dim { size: -107 } dim { size: 7 } dim { size: 7 } dim { size: 256 } } }
# W0000 00:00:1733953075.241033    1180 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -576 } dim { size: -577 } dim { size: -578 } dim { size: 256 } } } inputs { dtype: DT_FLOAT shape { dim { size: -107 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -107 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } value { dtype: DT_INT32 tensor_shape { dim { size: 2 } } int_val: 14 } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA GeForce RTX 4090" frequency: 2520 num_cores: 128 environment { key: "architecture" value: "8.9" } environment { key: "cuda" value: "12000" } environment { key: "cudnn" value: "8800" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 75497472 shared_memory_size_per_multiprocessor: 102400 memory_size: 22500343808 bandwidth: 1008096000 } outputs { dtype: DT_FLOAT shape { dim { size: -107 } dim { size: 14 } dim { size: 14 } dim { size: 256 } } }
# W0000 00:00:1733953075.241057    1180 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -565 } dim { size: -566 } dim { size: -567 } dim { size: 256 } } } inputs { dtype: DT_FLOAT shape { dim { size: -109 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -109 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } value { dtype: DT_INT32 tensor_shape { dim { size: 2 } } int_val: 7 } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA GeForce RTX 4090" frequency: 2520 num_cores: 128 environment { key: "architecture" value: "8.9" } environment { key: "cuda" value: "12000" } environment { key: "cudnn" value: "8800" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 75497472 shared_memory_size_per_multiprocessor: 102400 memory_size: 22500343808 bandwidth: 1008096000 } outputs { dtype: DT_FLOAT shape { dim { size: -109 } dim { size: 7 } dim { size: 7 } dim { size: 256 } } }
# W0000 00:00:1733953075.241087    1180 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -565 } dim { size: -566 } dim { size: -567 } dim { size: 256 } } } inputs { dtype: DT_FLOAT shape { dim { size: -109 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -109 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } value { dtype: DT_INT32 tensor_shape { dim { size: 2 } } int_val: 14 } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA GeForce RTX 4090" frequency: 2520 num_cores: 128 environment { key: "architecture" value: "8.9" } environment { key: "cuda" value: "12000" } environment { key: "cudnn" value: "8800" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 75497472 shared_memory_size_per_multiprocessor: 102400 memory_size: 22500343808 bandwidth: 1008096000 } outputs { dtype: DT_FLOAT shape { dim { size: -109 } dim { size: 14 } dim { size: 14 } dim { size: 256 } } }
# W0000 00:00:1733953075.241110    1180 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -552 } dim { size: -553 } dim { size: -554 } dim { size: 256 } } } inputs { dtype: DT_FLOAT shape { dim { size: -111 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -111 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } value { dtype: DT_INT32 tensor_shape { dim { size: 2 } } int_val: 7 } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA GeForce RTX 4090" frequency: 2520 num_cores: 128 environment { key: "architecture" value: "8.9" } environment { key: "cuda" value: "12000" } environment { key: "cudnn" value: "8800" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 75497472 shared_memory_size_per_multiprocessor: 102400 memory_size: 22500343808 bandwidth: 1008096000 } outputs { dtype: DT_FLOAT shape { dim { size: -111 } dim { size: 7 } dim { size: 7 } dim { size: 256 } } }
# W0000 00:00:1733953075.241139    1180 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -552 } dim { size: -553 } dim { size: -554 } dim { size: 256 } } } inputs { dtype: DT_FLOAT shape { dim { size: -111 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -111 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } value { dtype: DT_INT32 tensor_shape { dim { size: 2 } } int_val: 14 } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA GeForce RTX 4090" frequency: 2520 num_cores: 128 environment { key: "architecture" value: "8.9" } environment { key: "cuda" value: "12000" } environment { key: "cudnn" value: "8800" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 75497472 shared_memory_size_per_multiprocessor: 102400 memory_size: 22500343808 bandwidth: 1008096000 } outputs { dtype: DT_FLOAT shape { dim { size: -111 } dim { size: 14 } dim { size: 14 } dim { size: 256 } } }
# W0000 00:00:1733953075.241178    1180 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -535 } dim { size: -538 } dim { size: -539 } dim { size: 256 } } } inputs { dtype: DT_FLOAT shape { dim { size: -113 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -113 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } value { dtype: DT_INT32 tensor_shape { dim { size: 2 } } int_val: 7 } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA GeForce RTX 4090" frequency: 2520 num_cores: 128 environment { key: "architecture" value: "8.9" } environment { key: "cuda" value: "12000" } environment { key: "cudnn" value: "8800" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 75497472 shared_memory_size_per_multiprocessor: 102400 memory_size: 22500343808 bandwidth: 1008096000 } outputs { dtype: DT_FLOAT shape { dim { size: -113 } dim { size: 7 } dim { size: 7 } dim { size: 256 } } }
# W0000 00:00:1733953075.241211    1180 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -535 } dim { size: -538 } dim { size: -539 } dim { size: 256 } } } inputs { dtype: DT_FLOAT shape { dim { size: -113 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -113 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } value { dtype: DT_INT32 tensor_shape { dim { size: 2 } } int_val: 14 } } device { type: "GPU" vendor: "NVIDIA" model: "NVIDIA GeForce RTX 4090" frequency: 2520 num_cores: 128 environment { key: "architecture" value: "8.9" } environment { key: "cuda" value: "12000" } environment { key: "cudnn" value: "8800" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 75497472 shared_memory_size_per_multiprocessor: 102400 memory_size: 22500343808 bandwidth: 1008096000 } outputs { dtype: DT_FLOAT shape { dim { size: -113 } dim { size: 14 } dim { size: 14 } dim { size: 256 } } }
# 2500/2500 [==============================] - 501s 189ms/step - loss: 2.4508 - rpn_class_loss: 0.0378 - rpn_bbox_loss: 1.1352 - mrcnn_class_loss: 0.3176 - mrcnn_bbox_loss: 0.9147 - mrcnn_mask_loss: 0.5293 - val_loss: 3.1409 - val_rpn_class_loss: 0.0260 - val_rpn_bbox_loss: 1.1026 - val_mrcnn_class_loss: 0.6773 - val_mrcnn_bbox_loss: 0.6692 - val_mrcnn_mask_loss: 0.6658
# Epoch 3: Learning rate is 0.000300 (warmup phase).
# Epoch 3/200
# 2500/2500 [==============================] - 466s 186ms/step - loss: 1.0604 - rpn_class_loss: 0.0107 - rpn_bbox_loss: 0.3764 - mrcnn_class_loss: 0.2427 - mrcnn_bbox_loss: 0.2375 - mrcnn_mask_loss: 0.2926 - val_loss: 2.6607 - val_rpn_class_loss: 0.0324 - val_rpn_bbox_loss: 0.8927 - val_mrcnn_class_loss: 0.6358 - val_mrcnn_bbox_loss: 0.4719 - val_mrcnn_mask_loss: 0.6280
# Epoch 4: Learning rate is 0.000400 (warmup phase).
# Epoch 4/200
# 2500/2500 [==============================] - 464s 186ms/step - loss: 0.6888 - rpn_class_loss: 0.0073 - rpn_bbox_loss: 0.2401 - mrcnn_class_loss: 0.1270 - mrcnn_bbox_loss: 0.1353 - mrcnn_mask_loss: 0.2186 - val_loss: 2.3387 - val_rpn_class_loss: 0.0330 - val_rpn_bbox_loss: 0.7900 - val_mrcnn_class_loss: 0.5876 - val_mrcnn_bbox_loss: 0.3912 - val_mrcnn_mask_loss: 0.5370
# Epoch 5: Learning rate is 0.000500 (warmup phase).
# Epoch 5/200
# 2500/2500 [==============================] - 463s 185ms/step - loss: 0.5313 - rpn_class_loss: 0.0057 - rpn_bbox_loss: 0.1847 - mrcnn_class_loss: 0.0775 - mrcnn_bbox_loss: 0.1015 - mrcnn_mask_loss: 0.1781 - val_loss: 2.0241 - val_rpn_class_loss: 0.0304 - val_rpn_bbox_loss: 0.8279 - val_mrcnn_class_loss: 0.4380 - val_mrcnn_bbox_loss: 0.3130 - val_mrcnn_mask_loss: 0.4148
# Epoch 6: Learning rate is 0.000600 (warmup phase).
# Epoch 6/200
# 2500/2500 [==============================] - 463s 185ms/step - loss: 0.4517 - rpn_class_loss: 0.0047 - rpn_bbox_loss: 0.1592 - mrcnn_class_loss: 0.0562 - mrcnn_bbox_loss: 0.0833 - mrcnn_mask_loss: 0.1547 - val_loss: 1.9971 - val_rpn_class_loss: 0.0334 - val_rpn_bbox_loss: 1.0649 - val_mrcnn_class_loss: 0.3009 - val_mrcnn_bbox_loss: 0.2478 - val_mrcnn_mask_loss: 0.3501
# Epoch 7: Learning rate is 0.000700 (warmup phase).
# Epoch 7/200
# 2500/2500 [==============================] - 465s 186ms/step - loss: 0.4035 - rpn_class_loss: 0.0039 - rpn_bbox_loss: 0.1416 - mrcnn_class_loss: 0.0478 - mrcnn_bbox_loss: 0.0749 - mrcnn_mask_loss: 0.1423 - val_loss: 1.7767 - val_rpn_class_loss: 0.0270 - val_rpn_bbox_loss: 0.8093 - val_mrcnn_class_loss: 0.3761 - val_mrcnn_bbox_loss: 0.2550 - val_mrcnn_mask_loss: 0.3092
# Epoch 8: Learning rate is 0.000800 (warmup phase).
# Epoch 8/200
# 2500/2500 [==============================] - 464s 186ms/step - loss: 0.3657 - rpn_class_loss: 0.0034 - rpn_bbox_loss: 0.1310 - mrcnn_class_loss: 0.0394 - mrcnn_bbox_loss: 0.0674 - mrcnn_mask_loss: 0.1320 - val_loss: 1.6799 - val_rpn_class_loss: 0.0250 - val_rpn_bbox_loss: 0.8754 - val_mrcnn_class_loss: 0.2051 - val_mrcnn_bbox_loss: 0.2177 - val_mrcnn_mask_loss: 0.3567
# Epoch 9: Learning rate is 0.000900 (warmup phase).
# Epoch 9/200
# 2500/2500 [==============================] - 461s 184ms/step - loss: 0.3363 - rpn_class_loss: 0.0031 - rpn_bbox_loss: 0.1234 - mrcnn_class_loss: 0.0306 - mrcnn_bbox_loss: 0.0606 - mrcnn_mask_loss: 0.1211 - val_loss: 1.6210 - val_rpn_class_loss: 0.0190 - val_rpn_bbox_loss: 0.7196 - val_mrcnn_class_loss: 0.3132 - val_mrcnn_bbox_loss: 0.2131 - val_mrcnn_mask_loss: 0.3560
# Epoch 10: Learning rate is 0.001000 (warmup phase).
# Epoch 10/200
# 2500/2500 [==============================] - 462s 185ms/step - loss: 0.3210 - rpn_class_loss: 0.0029 - rpn_bbox_loss: 0.1219 - mrcnn_class_loss: 0.0306 - mrcnn_bbox_loss: 0.0562 - mrcnn_mask_loss: 0.1131 - val_loss: 1.2689 - val_rpn_class_loss: 0.0143 - val_rpn_bbox_loss: 0.5314 - val_mrcnn_class_loss: 0.2142 - val_mrcnn_bbox_loss: 0.2015 - val_mrcnn_mask_loss: 0.3076
# Epoch 11/200
# 2500/2500 [==============================] - 464s 185ms/step - loss: 0.2881 - rpn_class_loss: 0.0026 - rpn_bbox_loss: 0.1052 - mrcnn_class_loss: 0.0226 - mrcnn_bbox_loss: 0.0497 - mrcnn_mask_loss: 0.1074 - val_loss: 1.3802 - val_rpn_class_loss: 0.0142 - val_rpn_bbox_loss: 0.5216 - val_mrcnn_class_loss: 0.3479 - val_mrcnn_bbox_loss: 0.1796 - val_mrcnn_mask_loss: 0.3169
# Epoch 12/200
# 2500/2500 [==============================] - 463s 185ms/step - loss: 0.2625 - rpn_class_loss: 0.0022 - rpn_bbox_loss: 0.0955 - mrcnn_class_loss: 0.0199 - mrcnn_bbox_loss: 0.0459 - mrcnn_mask_loss: 0.1010 - val_loss: 1.2342 - val_rpn_class_loss: 0.0138 - val_rpn_bbox_loss: 0.4787 - val_mrcnn_class_loss: 0.2320 - val_mrcnn_bbox_loss: 0.1687 - val_mrcnn_mask_loss: 0.3409
# Epoch 13/200
# 2500/2500 [==============================] - 465s 186ms/step - loss: 0.2410 - rpn_class_loss: 0.0020 - rpn_bbox_loss: 0.0877 - mrcnn_class_loss: 0.0165 - mrcnn_bbox_loss: 0.0413 - mrcnn_mask_loss: 0.0946 - val_loss: 1.1334 - val_rpn_class_loss: 0.0136 - val_rpn_bbox_loss: 0.4899 - val_mrcnn_class_loss: 0.1989 - val_mrcnn_bbox_loss: 0.1524 - val_mrcnn_mask_loss: 0.2785
# Epoch 14/200
# 2500/2500 [==============================] - 463s 185ms/step - loss: 0.2245 - rpn_class_loss: 0.0018 - rpn_bbox_loss: 0.0794 - mrcnn_class_loss: 0.0154 - mrcnn_bbox_loss: 0.0383 - mrcnn_mask_loss: 0.0897 - val_loss: 1.2147 - val_rpn_class_loss: 0.0126 - val_rpn_bbox_loss: 0.6513 - val_mrcnn_class_loss: 0.1648 - val_mrcnn_bbox_loss: 0.1291 - val_mrcnn_mask_loss: 0.2569
# Epoch 15/200
# 2500/2500 [==============================] - 463s 185ms/step - loss: 0.2113 - rpn_class_loss: 0.0018 - rpn_bbox_loss: 0.0739 - mrcnn_class_loss: 0.0137 - mrcnn_bbox_loss: 0.0357 - mrcnn_mask_loss: 0.0867 - val_loss: 1.2352 - val_rpn_class_loss: 0.0129 - val_rpn_bbox_loss: 0.6805 - val_mrcnn_class_loss: 0.1602 - val_mrcnn_bbox_loss: 0.1449 - val_mrcnn_mask_loss: 0.2368
# Epoch 16/200
# 2500/2500 [==============================] - 463s 185ms/step - loss: 0.1976 - rpn_class_loss: 0.0017 - rpn_bbox_loss: 0.0681 - mrcnn_class_loss: 0.0130 - mrcnn_bbox_loss: 0.0336 - mrcnn_mask_loss: 0.0841 - val_loss: 1.2689 - val_rpn_class_loss: 0.0126 - val_rpn_bbox_loss: 0.6087 - val_mrcnn_class_loss: 0.2120 - val_mrcnn_bbox_loss: 0.1429 - val_mrcnn_mask_loss: 0.2927
# Epoch 17/200
# 2500/2500 [==============================] - 464s 186ms/step - loss: 0.1856 - rpn_class_loss: 0.0015 - rpn_bbox_loss: 0.0627 - mrcnn_class_loss: 0.0111 - mrcnn_bbox_loss: 0.0307 - mrcnn_mask_loss: 0.0798 - val_loss: 0.9186 - val_rpn_class_loss: 0.0101 - val_rpn_bbox_loss: 0.4396 - val_mrcnn_class_loss: 0.1180 - val_mrcnn_bbox_loss: 0.1163 - val_mrcnn_mask_loss: 0.2346
# Epoch 18/200
# 2500/2500 [==============================] - 464s 186ms/step - loss: 0.1771 - rpn_class_loss: 0.0014 - rpn_bbox_loss: 0.0600 - mrcnn_class_loss: 0.0095 - mrcnn_bbox_loss: 0.0295 - mrcnn_mask_loss: 0.0772 - val_loss: 1.0755 - val_rpn_class_loss: 0.0101 - val_rpn_bbox_loss: 0.5255 - val_mrcnn_class_loss: 0.1640 - val_mrcnn_bbox_loss: 0.1166 - val_mrcnn_mask_loss: 0.2593
# Epoch 19/200
# 2500/2500 [==============================] - 465s 186ms/step - loss: 0.1711 - rpn_class_loss: 0.0014 - rpn_bbox_loss: 0.0580 - mrcnn_class_loss: 0.0089 - mrcnn_bbox_loss: 0.0292 - mrcnn_mask_loss: 0.0759 - val_loss: 0.9981 - val_rpn_class_loss: 0.0097 - val_rpn_bbox_loss: 0.4375 - val_mrcnn_class_loss: 0.1725 - val_mrcnn_bbox_loss: 0.1155 - val_mrcnn_mask_loss: 0.2628
# Epoch 20/200
# 2500/2500 [==============================] - 465s 186ms/step - loss: 0.1538 - rpn_class_loss: 0.0012 - rpn_bbox_loss: 0.0474 - mrcnn_class_loss: 0.0079 - mrcnn_bbox_loss: 0.0246 - mrcnn_mask_loss: 0.0715 - val_loss: 1.1177 - val_rpn_class_loss: 0.0126 - val_rpn_bbox_loss: 0.6077 - val_mrcnn_class_loss: 0.1605 - val_mrcnn_bbox_loss: 0.1135 - val_mrcnn_mask_loss: 0.2234
# Epoch 21/200
# 2500/2500 [==============================] - 462s 185ms/step - loss: 0.1569 - rpn_class_loss: 0.0012 - rpn_bbox_loss: 0.0516 - mrcnn_class_loss: 0.0069 - mrcnn_bbox_loss: 0.0245 - mrcnn_mask_loss: 0.0717 - val_loss: 0.9324 - val_rpn_class_loss: 0.0092 - val_rpn_bbox_loss: 0.4538 - val_mrcnn_class_loss: 0.1198 - val_mrcnn_bbox_loss: 0.1092 - val_mrcnn_mask_loss: 0.2404
# Epoch 22/200
# 2500/2500 [==============================] - 465s 186ms/step - loss: 0.1469 - rpn_class_loss: 0.0012 - rpn_bbox_loss: 0.0464 - mrcnn_class_loss: 0.0073 - mrcnn_bbox_loss: 0.0233 - mrcnn_mask_loss: 0.0681 - val_loss: 1.1129 - val_rpn_class_loss: 0.0105 - val_rpn_bbox_loss: 0.5502 - val_mrcnn_class_loss: 0.2058 - val_mrcnn_bbox_loss: 0.1157 - val_mrcnn_mask_loss: 0.2307
# Epoch 23/200
# 2500/2500 [==============================] - 462s 185ms/step - loss: 0.1437 - rpn_class_loss: 9.9113e-04 - rpn_bbox_loss: 0.0453 - mrcnn_class_loss: 0.0072 - mrcnn_bbox_loss: 0.0216 - mrcnn_mask_loss: 0.0667 - val_loss: 0.8852 - val_rpn_class_loss: 0.0077 - val_rpn_bbox_loss: 0.3769 - val_mrcnn_class_loss: 0.1778 - val_mrcnn_bbox_loss: 0.1057 - val_mrcnn_mask_loss: 0.2171
# Epoch 24/200
# 2500/2500 [==============================] - 464s 186ms/step - loss: 0.1429 - rpn_class_loss: 0.0010 - rpn_bbox_loss: 0.0466 - mrcnn_class_loss: 0.0070 - mrcnn_bbox_loss: 0.0229 - mrcnn_mask_loss: 0.0674 - val_loss: 1.1436 - val_rpn_class_loss: 0.0101 - val_rpn_bbox_loss: 0.5795 - val_mrcnn_class_loss: 0.1682 - val_mrcnn_bbox_loss: 0.1134 - val_mrcnn_mask_loss: 0.2724
# Epoch 25/200
# 2500/2500 [==============================] - 461s 184ms/step - loss: 0.1304 - rpn_class_loss: 9.0190e-04 - rpn_bbox_loss: 0.0394 - mrcnn_class_loss: 0.0060 - mrcnn_bbox_loss: 0.0205 - mrcnn_mask_loss: 0.0646 - val_loss: 1.1364 - val_rpn_class_loss: 0.0118 - val_rpn_bbox_loss: 0.6706 - val_mrcnn_class_loss: 0.1427 - val_mrcnn_bbox_loss: 0.0977 - val_mrcnn_mask_loss: 0.2136
# Epoch 26/200
# 2500/2500 [==============================] - 464s 186ms/step - loss: 0.1254 - rpn_class_loss: 8.8347e-04 - rpn_bbox_loss: 0.0374 - mrcnn_class_loss: 0.0055 - mrcnn_bbox_loss: 0.0200 - mrcnn_mask_loss: 0.0633 - val_loss: 0.9654 - val_rpn_class_loss: 0.0100 - val_rpn_bbox_loss: 0.5233 - val_mrcnn_class_loss: 0.0983 - val_mrcnn_bbox_loss: 0.0939 - val_mrcnn_mask_loss: 0.2399
# Epoch 27/200
# 2500/2500 [==============================] - 462s 185ms/step - loss: 0.1246 - rpn_class_loss: 9.2026e-04 - rpn_bbox_loss: 0.0378 - mrcnn_class_loss: 0.0056 - mrcnn_bbox_loss: 0.0185 - mrcnn_mask_loss: 0.0614 - val_loss: 0.9211 - val_rpn_class_loss: 0.0093 - val_rpn_bbox_loss: 0.5358 - val_mrcnn_class_loss: 0.1066 - val_mrcnn_bbox_loss: 0.0858 - val_mrcnn_mask_loss: 0.1836
# Epoch 28/200
# 2500/2500 [==============================] - 464s 186ms/step - loss: 0.1232 - rpn_class_loss: 7.8535e-04 - rpn_bbox_loss: 0.0360 - mrcnn_class_loss: 0.0053 - mrcnn_bbox_loss: 0.0188 - mrcnn_mask_loss: 0.0614 - val_loss: 0.9503 - val_rpn_class_loss: 0.0095 - val_rpn_bbox_loss: 0.5356 - val_mrcnn_class_loss: 0.1107 - val_mrcnn_bbox_loss: 0.0949 - val_mrcnn_mask_loss: 0.1997
# Epoch 29/200
# 2500/2500 [==============================] - 462s 185ms/step - loss: 0.1185 - rpn_class_loss: 8.1499e-04 - rpn_bbox_loss: 0.0353 - mrcnn_class_loss: 0.0053 - mrcnn_bbox_loss: 0.0173 - mrcnn_mask_loss: 0.0584 - val_loss: 1.0567 - val_rpn_class_loss: 0.0099 - val_rpn_bbox_loss: 0.6467 - val_mrcnn_class_loss: 0.0900 - val_mrcnn_bbox_loss: 0.0912 - val_mrcnn_mask_loss: 0.2189
# Epoch 30/200
# 2500/2500 [==============================] - 464s 186ms/step - loss: 0.1102 - rpn_class_loss: 6.6311e-04 - rpn_bbox_loss: 0.0313 - mrcnn_class_loss: 0.0047 - mrcnn_bbox_loss: 0.0160 - mrcnn_mask_loss: 0.0571 - val_loss: 1.0657 - val_rpn_class_loss: 0.0098 - val_rpn_bbox_loss: 0.6070 - val_mrcnn_class_loss: 0.1632 - val_mrcnn_bbox_loss: 0.0891 - val_mrcnn_mask_loss: 0.1966
# Epoch 31/200
# 2500/2500 [==============================] - 451s 180ms/step - loss: nan - rpn_class_loss: nan - rpn_bbox_loss: nan - mrcnn_class_loss: nan - mrcnn_bbox_loss: 0.0108 - mrcnn_mask_loss: 0.0393 - val_loss: nan - val_rpn_class_loss: nan - val_rpn_bbox_loss: nan - val_mrcnn_class_loss: nan - val_mrcnn_bbox_loss: 0.0000e+00 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 32/200
# 2500/2500 [==============================] - 445s 178ms/step - loss: nan - rpn_class_loss: nan - rpn_bbox_loss: nan - mrcnn_class_loss: nan - mrcnn_bbox_loss: 0.0000e+00 - mrcnn_mask_loss: 0.0000e+00 - val_loss: nan - val_rpn_class_loss: nan - val_rpn_bbox_loss: nan - val_mrcnn_class_loss: nan - val_mrcnn_bbox_loss: 0.0000e+00 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 33/200
# 2500/2500 [==============================] - 445s 178ms/step - loss: nan - rpn_class_loss: nan - rpn_bbox_loss: nan - mrcnn_class_loss: nan - mrcnn_bbox_loss: 0.0000e+00 - mrcnn_mask_loss: 0.0000e+00 - val_loss: nan - val_rpn_class_loss: nan - val_rpn_bbox_loss: nan - val_mrcnn_class_loss: nan - val_mrcnn_bbox_loss: 0.0000e+00 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 34/200
# 2500/2500 [==============================] - 445s 178ms/step - loss: nan - rpn_class_loss: nan - rpn_bbox_loss: nan - mrcnn_class_loss: nan - mrcnn_bbox_loss: 0.0000e+00 - mrcnn_mask_loss: 0.0000e+00 - val_loss: nan - val_rpn_class_loss: nan - val_rpn_bbox_loss: nan - val_mrcnn_class_loss: nan - val_mrcnn_bbox_loss: 0.0000e+00 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 35/200
# 2500/2500 [==============================] - 445s 178ms/step - loss: nan - rpn_class_loss: nan - rpn_bbox_loss: nan - mrcnn_class_loss: nan - mrcnn_bbox_loss: 0.0000e+00 - mrcnn_mask_loss: 0.0000e+00 - val_loss: nan - val_rpn_class_loss: nan - val_rpn_bbox_loss: nan - val_mrcnn_class_loss: nan - val_mrcnn_bbox_loss: 0.0000e+00 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 36/200
# 2500/2500 [==============================] - 445s 178ms/step - loss: nan - rpn_class_loss: nan - rpn_bbox_loss: nan - mrcnn_class_loss: nan - mrcnn_bbox_loss: 0.0000e+00 - mrcnn_mask_loss: 0.0000e+00 - val_loss: nan - val_rpn_class_loss: nan - val_rpn_bbox_loss: nan - val_mrcnn_class_loss: nan - val_mrcnn_bbox_loss: 0.0000e+00 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 37/200
# 2500/2500 [==============================] - 444s 178ms/step - loss: nan - rpn_class_loss: nan - rpn_bbox_loss: nan - mrcnn_class_loss: nan - mrcnn_bbox_loss: 0.0000e+00 - mrcnn_mask_loss: 0.0000e+00 - val_loss: nan - val_rpn_class_loss: nan - val_rpn_bbox_loss: nan - val_mrcnn_class_loss: nan - val_mrcnn_bbox_loss: 0.0000e+00 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 38/200
# 2500/2500 [==============================] - 445s 178ms/step - loss: nan - rpn_class_loss: nan - rpn_bbox_loss: nan - mrcnn_class_loss: nan - mrcnn_bbox_loss: 0.0000e+00 - mrcnn_mask_loss: 0.0000e+00 - val_loss: nan - val_rpn_class_loss: nan - val_rpn_bbox_loss: nan - val_mrcnn_class_loss: nan - val_mrcnn_bbox_loss: 0.0000e+00 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 39/200
# 2500/2500 [==============================] - 445s 178ms/step - loss: nan - rpn_class_loss: nan - rpn_bbox_loss: nan - mrcnn_class_loss: nan - mrcnn_bbox_loss: 0.0000e+00 - mrcnn_mask_loss: 0.0000e+00 - val_loss: nan - val_rpn_class_loss: nan - val_rpn_bbox_loss: nan - val_mrcnn_class_loss: nan - val_mrcnn_bbox_loss: 0.0000e+00 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 40/200
# 2500/2500 [==============================] - 445s 178ms/step - loss: nan - rpn_class_loss: nan - rpn_bbox_loss: nan - mrcnn_class_loss: nan - mrcnn_bbox_loss: 0.0000e+00 - mrcnn_mask_loss: 0.0000e+00 - val_loss: nan - val_rpn_class_loss: nan - val_rpn_bbox_loss: nan - val_mrcnn_class_loss: nan - val_mrcnn_bbox_loss: 0.0000e+00 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 41/200
# 2500/2500 [==============================] - 444s 178ms/step - loss: nan - rpn_class_loss: nan - rpn_bbox_loss: nan - mrcnn_class_loss: nan - mrcnn_bbox_loss: 0.0000e+00 - mrcnn_mask_loss: 0.0000e+00 - val_loss: nan - val_rpn_class_loss: nan - val_rpn_bbox_loss: nan - val_mrcnn_class_loss: nan - val_mrcnn_bbox_loss: 0.0000e+00 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 42/200
# 2500/2500 [==============================] - 445s 178ms/step - loss: nan - rpn_class_loss: nan - rpn_bbox_loss: nan - mrcnn_class_loss: nan - mrcnn_bbox_loss: 0.0000e+00 - mrcnn_mask_loss: 0.0000e+00 - val_loss: nan - val_rpn_class_loss: nan - val_rpn_bbox_loss: nan - val_mrcnn_class_loss: nan - val_mrcnn_bbox_loss: 0.0000e+00 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 43/200
# 2500/2500 [==============================] - 444s 178ms/step - loss: nan - rpn_class_loss: nan - rpn_bbox_loss: nan - mrcnn_class_loss: nan - mrcnn_bbox_loss: 0.0000e+00 - mrcnn_mask_loss: 0.0000e+00 - val_loss: nan - val_rpn_class_loss: nan - val_rpn_bbox_loss: nan - val_mrcnn_class_loss: nan - val_mrcnn_bbox_loss: 0.0000e+00 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 44/200
# 2500/2500 [==============================] - 444s 178ms/step - loss: nan - rpn_class_loss: nan - rpn_bbox_loss: nan - mrcnn_class_loss: nan - mrcnn_bbox_loss: 0.0000e+00 - mrcnn_mask_loss: 0.0000e+00 - val_loss: nan - val_rpn_class_loss: nan - val_rpn_bbox_loss: nan - val_mrcnn_class_loss: nan - val_mrcnn_bbox_loss: 0.0000e+00 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 45/200
# 2500/2500 [==============================] - 445s 178ms/step - loss: nan - rpn_class_loss: nan - rpn_bbox_loss: nan - mrcnn_class_loss: nan - mrcnn_bbox_loss: 0.0000e+00 - mrcnn_mask_loss: 0.0000e+00 - val_loss: nan - val_rpn_class_loss: nan - val_rpn_bbox_loss: nan - val_mrcnn_class_loss: nan - val_mrcnn_bbox_loss: 0.0000e+00 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 46/200
# 2500/2500 [==============================] - 443s 177ms/step - loss: nan - rpn_class_loss: nan - rpn_bbox_loss: nan - mrcnn_class_loss: nan - mrcnn_bbox_loss: 0.0000e+00 - mrcnn_mask_loss: 0.0000e+00 - val_loss: nan - val_rpn_class_loss: nan - val_rpn_bbox_loss: nan - val_mrcnn_class_loss: nan - val_mrcnn_bbox_loss: 0.0000e+00 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 47/200
# 2500/2500 [==============================] - 444s 178ms/step - loss: nan - rpn_class_loss: nan - rpn_bbox_loss: nan - mrcnn_class_loss: nan - mrcnn_bbox_loss: 0.0000e+00 - mrcnn_mask_loss: 0.0000e+00 - val_loss: nan - val_rpn_class_loss: nan - val_rpn_bbox_loss: nan - val_mrcnn_class_loss: nan - val_mrcnn_bbox_loss: 0.0000e+00 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 48/200
# 2500/2500 [==============================] - 445s 178ms/step - loss: nan - rpn_class_loss: nan - rpn_bbox_loss: nan - mrcnn_class_loss: nan - mrcnn_bbox_loss: 0.0000e+00 - mrcnn_mask_loss: 0.0000e+00 - val_loss: nan - val_rpn_class_loss: nan - val_rpn_bbox_loss: nan - val_mrcnn_class_loss: nan - val_mrcnn_bbox_loss: 0.0000e+00 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 49/200
# 2500/2500 [==============================] - 445s 178ms/step - loss: nan - rpn_class_loss: nan - rpn_bbox_loss: nan - mrcnn_class_loss: nan - mrcnn_bbox_loss: 0.0000e+00 - mrcnn_mask_loss: 0.0000e+00 - val_loss: nan - val_rpn_class_loss: nan - val_rpn_bbox_loss: nan - val_mrcnn_class_loss: nan - val_mrcnn_bbox_loss: 0.0000e+00 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 50/200
# 2500/2500 [==============================] - 446s 178ms/step - loss: nan - rpn_class_loss: nan - rpn_bbox_loss: nan - mrcnn_class_loss: nan - mrcnn_bbox_loss: 0.0000e+00 - mrcnn_mask_loss: 0.0000e+00 - val_loss: nan - val_rpn_class_loss: nan - val_rpn_bbox_loss: nan - val_mrcnn_class_loss: nan - val_mrcnn_bbox_loss: 0.0000e+00 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 51/200
# 2500/2500 [==============================] - 445s 178ms/step - loss: nan - rpn_class_loss: nan - rpn_bbox_loss: nan - mrcnn_class_loss: nan - mrcnn_bbox_loss: 0.0000e+00 - mrcnn_mask_loss: 0.0000e+00 - val_loss: nan - val_rpn_class_loss: nan - val_rpn_bbox_loss: nan - val_mrcnn_class_loss: nan - val_mrcnn_bbox_loss: 0.0000e+00 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 52/200
# 2500/2500 [==============================] - 446s 178ms/step - loss: nan - rpn_class_loss: nan - rpn_bbox_loss: nan - mrcnn_class_loss: nan - mrcnn_bbox_loss: 0.0000e+00 - mrcnn_mask_loss: 0.0000e+00 - val_loss: nan - val_rpn_class_loss: nan - val_rpn_bbox_loss: nan - val_mrcnn_class_loss: nan - val_mrcnn_bbox_loss: 0.0000e+00 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 53/200
# 2500/2500 [==============================] - 446s 178ms/step - loss: nan - rpn_class_loss: nan - rpn_bbox_loss: nan - mrcnn_class_loss: nan - mrcnn_bbox_loss: 0.0000e+00 - mrcnn_mask_loss: 0.0000e+00 - val_loss: nan - val_rpn_class_loss: nan - val_rpn_bbox_loss: nan - val_mrcnn_class_loss: nan - val_mrcnn_bbox_loss: 0.0000e+00 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 54/200
# 2500/2500 [==============================] - 445s 178ms/step - loss: nan - rpn_class_loss: nan - rpn_bbox_loss: nan - mrcnn_class_loss: nan - mrcnn_bbox_loss: 0.0000e+00 - mrcnn_mask_loss: 0.0000e+00 - val_loss: nan - val_rpn_class_loss: nan - val_rpn_bbox_loss: nan - val_mrcnn_class_loss: nan - val_mrcnn_bbox_loss: 0.0000e+00 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 55/200
# 2500/2500 [==============================] - 444s 178ms/step - loss: nan - rpn_class_loss: nan - rpn_bbox_loss: nan - mrcnn_class_loss: nan - mrcnn_bbox_loss: 0.0000e+00 - mrcnn_mask_loss: 0.0000e+00 - val_loss: nan - val_rpn_class_loss: nan - val_rpn_bbox_loss: nan - val_mrcnn_class_loss: nan - val_mrcnn_bbox_loss: 0.0000e+00 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 56/200
# 2500/2500 [==============================] - 444s 178ms/step - loss: nan - rpn_class_loss: nan - rpn_bbox_loss: nan - mrcnn_class_loss: nan - mrcnn_bbox_loss: 0.0000e+00 - mrcnn_mask_loss: 0.0000e+00 - val_loss: nan - val_rpn_class_loss: nan - val_rpn_bbox_loss: nan - val_mrcnn_class_loss: nan - val_mrcnn_bbox_loss: 0.0000e+00 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 57/200
# 2500/2500 [==============================] - 445s 178ms/step - loss: nan - rpn_class_loss: nan - rpn_bbox_loss: nan - mrcnn_class_loss: nan - mrcnn_bbox_loss: 0.0000e+00 - mrcnn_mask_loss: 0.0000e+00 - val_loss: nan - val_rpn_class_loss: nan - val_rpn_bbox_loss: nan - val_mrcnn_class_loss: nan - val_mrcnn_bbox_loss: 0.0000e+00 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 58/200
# 2500/2500 [==============================] - 445s 178ms/step - loss: nan - rpn_class_loss: nan - rpn_bbox_loss: nan - mrcnn_class_loss: nan - mrcnn_bbox_loss: 0.0000e+00 - mrcnn_mask_loss: 0.0000e+00 - val_loss: nan - val_rpn_class_loss: nan - val_rpn_bbox_loss: nan - val_mrcnn_class_loss: nan - val_mrcnn_bbox_loss: 0.0000e+00 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 59/200
# 2500/2500 [==============================] - 445s 178ms/step - loss: nan - rpn_class_loss: nan - rpn_bbox_loss: nan - mrcnn_class_loss: nan - mrcnn_bbox_loss: 0.0000e+00 - mrcnn_mask_loss: 0.0000e+00 - val_loss: nan - val_rpn_class_loss: nan - val_rpn_bbox_loss: nan - val_mrcnn_class_loss: nan - val_mrcnn_bbox_loss: 0.0000e+00 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 60/200
# 2500/2500 [==============================] - 445s 178ms/step - loss: nan - rpn_class_loss: nan - rpn_bbox_loss: nan - mrcnn_class_loss: nan - mrcnn_bbox_loss: 0.0000e+00 - mrcnn_mask_loss: 0.0000e+00 - val_loss: nan - val_rpn_class_loss: nan - val_rpn_bbox_loss: nan - val_mrcnn_class_loss: nan - val_mrcnn_bbox_loss: 0.0000e+00 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 61/200
# 2500/2500 [==============================] - 445s 178ms/step - loss: nan - rpn_class_loss: nan - rpn_bbox_loss: nan - mrcnn_class_loss: nan - mrcnn_bbox_loss: 0.0000e+00 - mrcnn_mask_loss: 0.0000e+00 - val_loss: nan - val_rpn_class_loss: nan - val_rpn_bbox_loss: nan - val_mrcnn_class_loss: nan - val_mrcnn_bbox_loss: 0.0000e+00 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 62/200
# 2500/2500 [==============================] - 447s 179ms/step - loss: nan - rpn_class_loss: nan - rpn_bbox_loss: nan - mrcnn_class_loss: nan - mrcnn_bbox_loss: 0.0000e+00 - mrcnn_mask_loss: 0.0000e+00 - val_loss: nan - val_rpn_class_loss: nan - val_rpn_bbox_loss: nan - val_mrcnn_class_loss: nan - val_mrcnn_bbox_loss: 0.0000e+00 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 63/200
# 2500/2500 [==============================] - 445s 178ms/step - loss: nan - rpn_class_loss: nan - rpn_bbox_loss: nan - mrcnn_class_loss: nan - mrcnn_bbox_loss: 0.0000e+00 - mrcnn_mask_loss: 0.0000e+00 - val_loss: nan - val_rpn_class_loss: nan - val_rpn_bbox_loss: nan - val_mrcnn_class_loss: nan - val_mrcnn_bbox_loss: 0.0000e+00 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 64/200
# 2500/2500 [==============================] - 445s 178ms/step - loss: nan - rpn_class_loss: nan - rpn_bbox_loss: nan - mrcnn_class_loss: nan - mrcnn_bbox_loss: 0.0000e+00 - mrcnn_mask_loss: 0.0000e+00 - val_loss: nan - val_rpn_class_loss: nan - val_rpn_bbox_loss: nan - val_mrcnn_class_loss: nan - val_mrcnn_bbox_loss: 0.0000e+00 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 65/200
# 2500/2500 [==============================] - 445s 178ms/step - loss: nan - rpn_class_loss: nan - rpn_bbox_loss: nan - mrcnn_class_loss: nan - mrcnn_bbox_loss: 0.0000e+00 - mrcnn_mask_loss: 0.0000e+00 - val_loss: nan - val_rpn_class_loss: nan - val_rpn_bbox_loss: nan - val_mrcnn_class_loss: nan - val_mrcnn_bbox_loss: 0.0000e+00 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 66/200
# 2500/2500 [==============================] - 445s 178ms/step - loss: nan - rpn_class_loss: nan - rpn_bbox_loss: nan - mrcnn_class_loss: nan - mrcnn_bbox_loss: 0.0000e+00 - mrcnn_mask_loss: 0.0000e+00 - val_loss: nan - val_rpn_class_loss: nan - val_rpn_bbox_loss: nan - val_mrcnn_class_loss: nan - val_mrcnn_bbox_loss: 0.0000e+00 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 67/200
# 2500/2500 [==============================] - 445s 178ms/step - loss: nan - rpn_class_loss: nan - rpn_bbox_loss: nan - mrcnn_class_loss: nan - mrcnn_bbox_loss: 0.0000e+00 - mrcnn_mask_loss: 0.0000e+00 - val_loss: nan - val_rpn_class_loss: nan - val_rpn_bbox_loss: nan - val_mrcnn_class_loss: nan - val_mrcnn_bbox_loss: 0.0000e+00 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 68/200
# 2500/2500 [==============================] - 445s 178ms/step - loss: nan - rpn_class_loss: nan - rpn_bbox_loss: nan - mrcnn_class_loss: nan - mrcnn_bbox_loss: 0.0000e+00 - mrcnn_mask_loss: 0.0000e+00 - val_loss: nan - val_rpn_class_loss: nan - val_rpn_bbox_loss: nan - val_mrcnn_class_loss: nan - val_mrcnn_bbox_loss: 0.0000e+00 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 69/200
# 2500/2500 [==============================] - 447s 179ms/step - loss: nan - rpn_class_loss: nan - rpn_bbox_loss: nan - mrcnn_class_loss: nan - mrcnn_bbox_loss: 0.0000e+00 - mrcnn_mask_loss: 0.0000e+00 - val_loss: nan - val_rpn_class_loss: nan - val_rpn_bbox_loss: nan - val_mrcnn_class_loss: nan - val_mrcnn_bbox_loss: 0.0000e+00 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 70/200
# 2500/2500 [==============================] - 445s 178ms/step - loss: nan - rpn_class_loss: nan - rpn_bbox_loss: nan - mrcnn_class_loss: nan - mrcnn_bbox_loss: 0.0000e+00 - mrcnn_mask_loss: 0.0000e+00 - val_loss: nan - val_rpn_class_loss: nan - val_rpn_bbox_loss: nan - val_mrcnn_class_loss: nan - val_mrcnn_bbox_loss: 0.0000e+00 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 71/200
# 2500/2500 [==============================] - 446s 178ms/step - loss: nan - rpn_class_loss: nan - rpn_bbox_loss: nan - mrcnn_class_loss: nan - mrcnn_bbox_loss: 0.0000e+00 - mrcnn_mask_loss: 0.0000e+00 - val_loss: nan - val_rpn_class_loss: nan - val_rpn_bbox_loss: nan - val_mrcnn_class_loss: nan - val_mrcnn_bbox_loss: 0.0000e+00 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 72/200
# 2500/2500 [==============================] - 445s 178ms/step - loss: nan - rpn_class_loss: nan - rpn_bbox_loss: nan - mrcnn_class_loss: nan - mrcnn_bbox_loss: 0.0000e+00 - mrcnn_mask_loss: 0.0000e+00 - val_loss: nan - val_rpn_class_loss: nan - val_rpn_bbox_loss: nan - val_mrcnn_class_loss: nan - val_mrcnn_bbox_loss: 0.0000e+00 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 73/200
# 2500/2500 [==============================] - 446s 178ms/step - loss: nan - rpn_class_loss: nan - rpn_bbox_loss: nan - mrcnn_class_loss: nan - mrcnn_bbox_loss: 0.0000e+00 - mrcnn_mask_loss: 0.0000e+00 - val_loss: nan - val_rpn_class_loss: nan - val_rpn_bbox_loss: nan - val_mrcnn_class_loss: nan - val_mrcnn_bbox_loss: 0.0000e+00 - val_mrcnn_mask_loss: 0.0000e+00

# %%
epochs = range(len(list(history["loss"])))
epochs = tuple(e + 1 for e in epochs)


plt.figure(figsize=(18, 6))

plt.subplot(131, title="losses")
plt.plot(epochs, history["loss"], label="train loss")
plt.plot(epochs, history["val_loss"], label="valid loss")
plt.xticks(range(0, epochs[-1]+1, 20))
plt.yscale("log")
for xpos in (epochs[0], epochs[-1]):
    plt.axvline(x=xpos, color="gray", linestyle="--", linewidth=1)
plt.legend()

plt.subplot(132)
plt.plot(epochs, history["mrcnn_class_loss"], label="train class loss")
plt.plot(epochs, history["val_mrcnn_class_loss"], label="valid class loss")
plt.xticks(range(0, epochs[-1]+1, 20))
plt.yscale("log")
for xpos in (epochs[0], epochs[-1]):
    plt.axvline(x=xpos, color="gray", linestyle="--", linewidth=1)
plt.legend()

plt.subplot(133)
plt.plot(epochs, history["mrcnn_mask_loss"], label="train mask loss")
plt.plot(epochs, history["val_mrcnn_mask_loss"], label="valid mask loss")
plt.xticks(range(0, epochs[-1]+1, 20))
plt.yscale("log")
for xpos in (epochs[0], epochs[-1]):
    plt.axvline(x=xpos, color="gray", linestyle="--", linewidth=1)
plt.legend()

plt.show()

# %%
class InferenceConfig(ShapesConfig):
    GPU_COUNT = 1
    IMAGES_PER_GPU = 1

inference_config = InferenceConfig()

# Recreate the model in inference mode
model = modellib.MaskRCNN(mode="inference", 
                          config=inference_config,
                          model_dir=dir_model)

# Get path to saved weights
# Either set a specific path or find last trained weights
# model_path = os.path.join(ROOT_DIR, ".h5 file name here")
model_path = model.find_last()

# Load trained weights
print("Loading weights from ", model_path)
model.load_weights(model_path, by_name=True)
# Out:
# Loading weights from  /mnt/c/Users/ChangGeng/Desktop/FAU/Semester 07/Bachelorarbeit/02_Vision_Transformers/SHVIT_Mask_RCNN/logs/60_shapes_shvit20241211T2226/mask_rcnn_60_shapes_shvit_0023.h5
# Re-starting from epoch 23

# %%
image = cv2.imread("./shape_test_images/shape_test_image_8.png") # check if image in folder exists - otherwise change name, if necessary

# Run detection
results = model.detect([image], verbose=1)
res = results[0]
print(res["rois"])
print(res["class_ids"])
print(res["scores"])
print(dataset_val.class_names)

# Visualize results
visualize.display_instances(image, res["rois"], res["masks"], res["class_ids"], dataset_val.class_names, res["scores"], figsize=(8, 8))
# Out:
# Processing 1 images
# image
# [ WARN:0@31528.483] global loadsave.cpp:248 findDecoder imread_('./shape_test_images/shape_test_image_8.png'): can't open/read file: check file path/integrity
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 4
#       1 image = cv2.imread("./shape_test_images/shape_test_image_8.png") # check if image in folder exists - otherwise change name, if necessary
#       3 # Run detection
# ----> 4 results = model.detect([image], verbose=1)
#       5 res = results[0]
#       6 print(res["rois"])
#
# File /mnt/c/Users/ChangGeng/Desktop/FAU/Semester 07/Bachelorarbeit/02_Vision_Transformers/SHVIT_Mask_RCNN/mrcnn/model.py:2699, in MaskRCNN.detect(self, images, verbose)
#    2696         log("image", image)
#    2698 # Mold inputs to format expected by the neural network
# -> 2699 molded_images, image_metas, windows = self.mold_inputs(images)
#    2701 # Validate image sizes
#    2702 # All images in a batch MUST be of the same size
#    2703 image_shape = molded_images[0].shape
#
# File /mnt/c/Users/ChangGeng/Desktop/FAU/Semester 07/Bachelorarbeit/02_Vision_Transformers/SHVIT_Mask_RCNN/mrcnn/model.py:2592, in MaskRCNN.mold_inputs(self, images)
#    2588 windows = []
#    2589 for image in images:
#    2590     # Resize image
#    2591     # TODO: move resizing to mold_image()
# -> 2592     molded_image, window, scale, padding, crop = utils.resize_image(
#    2593         image,
#    2594         min_dim=self.config.IMAGE_MIN_DIM,
#    2595         min_scale=self.config.IMAGE_MIN_SCALE,
#    2596         max_dim=self.config.IMAGE_MAX_DIM,
#    2597         mode=self.config.IMAGE_RESIZE_MODE)
#    2598     molded_image = mold_image(molded_image, self.config)
#    2599     # Build image_meta
#
# File /mnt/c/Users/ChangGeng/Desktop/FAU/Semester 07/Bachelorarbeit/02_Vision_Transformers/SHVIT_Mask_RCNN/mrcnn/utils.py:418, in resize_image(image, min_dim, max_dim, min_scale, mode)
#     386 """Resizes an image keeping the aspect ratio unchanged.
#     387
#     388 min_dim: if provided, resizes the image such that it's smaller
#    (...)
#     415 padding: Padding added to the image [(top, bottom), (left, right), (0, 0)]
#     416 """
#     417 # Keep track of image dtype and return results in the same dtype
# --> 418 image_dtype = image.dtype
#     419 # Default window (y1, x1, y2, x2) and default scale == 1.
#     420 h, w = image.shape[:2]
#
# AttributeError: 'NoneType' object has no attribute 'dtype'

# %%
# Test on a random image
image_id = random.choice(dataset_val.image_ids)
original_image, image_meta, gt_class_id, gt_bbox, gt_mask =\
    modellib.load_image_gt(dataset_val, inference_config, 
                           image_id, use_mini_mask=False)

log("original_image", original_image)
log("image_meta", image_meta)
log("gt_class_id", gt_class_id) # ground truth
log("gt_bbox", gt_bbox) # ground truth
log("gt_mask", gt_mask) # ground truth

# visualize.display_instances(original_image, gt_bbox, gt_mask, gt_class_id, 
#                             dataset_val.class_names, figsize=(8, 8))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Test on a random image
# ----> 2 image_id = random.choice(dataset_val.image_ids)
#       3 original_image, image_meta, gt_class_id, gt_bbox, gt_mask =\
#       4     modellib.load_image_gt(dataset_val, inference_config,
#       5                            image_id, use_mini_mask=False)
#       7 log("original_image", original_image)
#
# NameError: name 'random' is not defined
